# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
import plotly.express as px
import plotly.graph_objs as go
import pickle
from urllib.request import urlopen
import json
from jupyter_dash import JupyterDash
from dash import Dash, dcc, html, Input, Output

# %% [markdown]
# # Часть 1. Предобработка данных

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
train.shape
# Out:
# (30471, 292)

# %%
def preprocessing_date(data):
    data['timestamp'] = pd.to_datetime(data['timestamp'])
    data['year'] = data['timestamp'].dt.year
    data['month'] = data['timestamp'].dt.month

    return data

# %%
train = preprocessing_date(train)
test = preprocessing_date(test)

# %%
target = train['price_doc']
id_test = test['id']

# %% [markdown]
# Удалим признаки не содержащие информации

# %%
dropped_feat = ['price_doc', 'timestamp', 'id', 'ID_metro', 
                'raion_build_count_with_material_info',
                'raion_build_count_with_builddate_info',
                'ID_railroad_station_walk', "ID_railroad_station_avto",
                "ID_big_road1", "ID_big_road2", "ID_railroad_terminal",
                "ID_bus_terminal"]

# %%
for feat in dropped_feat:
    if feat in test.columns:
        test = test.drop(feat, axis=1)
    train = train.drop(feat, axis=1)

# %% [markdown]
# Проверим на наличие пропущеных значений

# %%
train.isna().sum()[train.isna().sum() > 0]
# Out:
# life_sq                         6383
# floor                            167
# max_floor                       9572
# material                        9572
# build_year                     13605
# num_room                        9572
# kitch_sq                        9572
# state                          13559
# preschool_quota                 6688
# school_quota                    6685
# hospital_beds_raion            14441
# build_count_block               4991
# build_count_wood                4991
# build_count_frame               4991
# build_count_brick               4991
# build_count_monolith            4991
# build_count_panel               4991
# build_count_foam                4991
# build_count_slag                4991
# build_count_mix                 4991
# build_count_before_1920         4991
# build_count_1921-1945           4991
# build_count_1946-1970           4991
# build_count_1971-1995           4991
# build_count_after_1995          4991
# metro_min_walk                    25
# metro_km_walk                     25
# railroad_station_walk_km          25
# railroad_station_walk_min         25
# cafe_sum_500_min_price_avg     13281
# cafe_sum_500_max_price_avg     13281
# cafe_avg_price_500             13281
# cafe_sum_1000_min_price_avg     6524
# cafe_sum_1000_max_price_avg     6524
# cafe_avg_price_1000             6524
# cafe_sum_1500_min_price_avg     4199
# cafe_sum_1500_max_price_avg     4199
# cafe_avg_price_1500             4199
# cafe_sum_2000_min_price_avg     1725
# cafe_sum_2000_max_price_avg     1725
# cafe_avg_price_2000             1725
# cafe_sum_3000_min_price_avg      991
# cafe_sum_3000_max_price_avg      991
# cafe_avg_price_3000              991
# prom_part_5000                   178
# cafe_sum_5000_min_price_avg      297
# cafe_sum_5000_max_price_avg      297
# cafe_avg_price_5000              297
# dtype: int64

# %% [markdown]
# Разделим данные на категориальные и вещественные

# %%
cat_feat = ['material', 'state', 'product_type', 'sub_area', 'culture_objects_top_25', 
 'thermal_power_plant_raion', 'incineration_raion', 'oil_chemistry_raion', 
 'radiation_raion', 'railroad_terminal_raion', 'big_market_raion', 
 'nuclear_reactor_raion', 'detention_facility_raion', 'water_1line', 
 'big_road1_1line', 'railroad_1line', 'ecology']

# %%
num_feat = [x for x in train.columns if x not in cat_feat]

# %% [markdown]
# Заполним пропуски данных

# %%
imp_most_frequent = SimpleImputer(strategy='most_frequent')
imp_median = SimpleImputer(strategy='median')

# заполнение категориальных признаков
cat_train = pd.DataFrame(imp_most_frequent.fit_transform(train[cat_feat]), 
                         columns=cat_feat)

cat_test = pd.DataFrame(imp_most_frequent.transform(test[cat_feat]),
                        columns=cat_feat)

cat_train = cat_train.astype(train[cat_feat].dtypes)
cat_test = cat_test.astype(test[cat_feat].dtypes)

# заполненеие вещественных признаков
num_train = pd.DataFrame(imp_median.fit_transform(train[num_feat]),
                 columns=num_feat)

num_test = pd.DataFrame(imp_median.transform(test[num_feat]),
                 columns=num_feat)

num_train = num_train.astype(train[num_feat].dtypes)
num_test = num_test.astype(test[num_feat].dtypes)

# объединим заполненые данные
train = pd.concat([num_train, cat_train], axis=1)
test = pd.concat([num_test, cat_test], axis=1)

# %% [markdown]
# Откорректируем данные

# %%
def correct_values(data):
  # приравниваем жилую площадь к общей, там где она превышает общую
  bad_index = data[data['full_sq'] < data['life_sq']].index
  data.loc[bad_index, ['life_sq']] = data.loc[bad_index, ['full_sq']]
  
  # убираем слишком большие и маленькие годы постройки
  data.loc[data['build_year']<1500, 'build_year'] = np.NaN
  data.loc[data['build_year']>2020, 'build_year'] = np.NaN
  
  # убираем нулевые значения количества комнат
  data.loc[data['num_room']==0, 'num_room'] = np.NaN
  
  # приравниваем этажность здания к этажу объекта там где она меньше
  bad_index = data[data['max_floor'] < data['floor']].index
  data.loc[bad_index, ['max_floor']] = data.loc[bad_index, ['floor']]
  
  # исправляем опечатку в данных
  data['state'] = data['state'].replace(33,3)
  
  # убираем площадь кухни где она больше общей площади
  bad_index = data[data['full_sq'] < data['kitch_sq']].index
  data.loc[bad_index, ['kitch_sq']] = np.NaN
  
  # корректировка типа данных
  data['material'] = data['material'].astype('int64')
  data['state'] = data['state'].astype('int64')

  return data

# %%
train = correct_values(train)
test = correct_values(test)

# %%
# выгрузим обработанные данные
train.to_csv('processed_data.csv', index=False)

# %% [markdown]
# Для выполнения задания школы DS разделим тренировочные данные на тренировочные и тестовые, т.к. они имеют целевую переменную и далее будем работать с ними.

# %%
def split_data(data, target, train_share):
  share = round(len(data)*train_share)
  X_train, y_train = data.iloc[:share,:], target[:share]
  X_test, y_test = data.iloc[share:,:], target[share:]

  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_data(train, target, train_share=0.8)

# %% [markdown]
# # Часть 2. Расчет модели

# %% [markdown]
# Будем использовать алгоритм градиентного бустинга из библиотеки CatBoost. В данном алгоритме кодировка категориальных признаков проводится внутри самого алгоритма, поэтому ненужно предварительно подготавливать данные. Кроме этого алгоритм основа на Decision Trees для которых нет необходимости проводить масштабирование вещественных признаков.

# %%
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import mean_squared_log_error

# %%
train_dataset = Pool(X_train, y_train, cat_features=cat_feat)                                                      
test_dataset = Pool(X_test, y_test, cat_features=cat_feat)

# %%
# выбор оптимального количества деревьев
model = CatBoostRegressor(iterations=5000)
model.fit(train_dataset, 
          use_best_model=True,
          eval_set=test_dataset, silent=True)
best_iter = model.tree_count_
best_iter
# Out:
# 4755

# %%
mean_squared_log_error(y_test, model.predict(X_test))**0.5
# Out:
# 0.40821152729773036

# %%
# обучаем модель со всеми фичами
model = CatBoostRegressor(iterations=best_iter)
model.fit(train_dataset, silent=True)

# %%
mean_squared_log_error(y_test, model.predict(X_test))**0.5
# Out:
# 0.4075278724367229

# %% [markdown]
# Рассмотрим важность признаков и посмотрим как будет изменяться метрика RMSLE при уменьшении количества признаков.

# %%
feature = model.feature_names_
importance = model.feature_importances_
rank = np.arange(1, len(feature) + 1)
name = ['feature', 'importance']
df = pd.DataFrame(zip(feature, importance), 
                  columns=name).sort_values('importance', ascending=False)
df['rank'] = rank

# %%
best_count_feat = len(df)
best_RMSLE = 1
score = {}
for i in range(len(df), 0, -20):
    columns = df['feature'][0:i]
    temp_cat_feat = [x for x in cat_feat if x in columns.to_list()]
    train_dataset = Pool(X_train[columns], y_train, cat_features=temp_cat_feat)  
    model = CatBoostRegressor(iterations=best_iter)
    model.fit(train_dataset, silent=True)
    RMSLE = mean_squared_log_error(y_test, model.predict(X_test[columns]))**0.5
    score[len(columns)] = round(RMSLE,4)
    if RMSLE < best_RMSLE:
        best_RMSLE = RMSLE
        best_count_feat = i

# %%
import json
with open('score.json', 'w') as outfile:
    json.dump(score, outfile)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=list(score.keys()),
    y=list(score.values()),
    mode="lines+markers+text",
    name="Lines, Markers and Text",
    text=list(score.values()),
    textposition="top center"
))
fig.update_xaxes(title_text='Count of features')
fig.update_yaxes(title_text='RMSLE')
fig.show()
# Out:
# <div>                            <div id="ed7ad975-c9b6-4531-a481-270fdf8f5523" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed7ad975-c9b6-4531-a481-270fdf8f5523")) {                    Plotly.newPlot(                        "ed7ad975-c9b6-4531-a481-270fdf8f5523",                        [{"mode":"lines+markers+text","name":"Lines, Markers and Text","text":["0.4088","0.408","0.4079","0.4082","0.4084","0.4078","0.4079","0.4074","0.407","0.408","0.4088","0.4082","0.4097","0.4104","0.4909"],"textposition":"top center","x":[282,262,242,222,202,182,162,142,122,102,82,62,42,22,2],"y":[0.4088,0.408,0.4079,0.4082,0.4084,0.4078,0.4079,0.4074,0.407,0.408,0.4088,0.4082,0.4097,0.4104,0.4909],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth": ...

# %% [markdown]
# Вывод: можем сократить количество признаков до ** (отобрав наибоолее важные) без снижения качества модели.

# %%
best_count_feat = 122+1

# %%
pd.set_option('max_rows', None)
print(f'{best_count_feat} most important features')
df.head(best_count_feat)
#df[df['feature'] == 'material']
# Out:
# 123 most important features
#                             feature  importance  rank
# 0                           full_sq   37.373690     1
# 263                            year    1.996224     2
# 4                        build_year    1.895479     3
# 266                           state    1.697949     4
# 1                           life_sq    1.565857     5
# 2                             floor    1.350315     6
# 268                        sub_area    1.341102     7
# 254      cafe_count_5000_price_2500    1.265242     8
# 231      cafe_count_3000_price_2500    1.138517     9
# 256      cafe_count_5000_price_high    1.124648    10
# 5                          num_room    1.012380    11
# 6                          kitch_sq    0.996056    12
# 223                 cafe_count_3000    0.872168    13
# 230      cafe_count_3000_price_1500    0.832777    14
# 3                         max_floor    0.810946    15
# 200                 cafe_count_2000    0.712884    16
# 219               office_count_3000    0.630336    17
# 83      public_transport_station_km    0.612869    18
# 267                    product_type    0.611793    19
# 74                    green_zone_km    0.609677    20
# 111            public_healthcare_km    0.608396    21
# 93                      railroad_km    0.584667    22
# 208      cafe_count_2000_price_2500    0.581622    23
# 121                      theater_km    0.576812    24
# 10                      indust_part    0.573511    25
# 116         additional_education_km    0.569902    26
# 105                    swim_pool_km    0.523147    27
# 71                  kindergarten_km    0.506400    28
# 104                      fitness_km    0.482220    29
# 18              hospital_beds_raion    0.481351    30
# 238                sport_count_3000    0.480518    31
# 57             build_count_monolith    0.475781    32
# 198                  trc_count_2000    0.453748    33
# 264                           month    0.450850    34
# 253      cafe_count_5000_price_1500    0.450615    35
# 88                       sadovoe_km    0.442450    36
# 177                 cafe_count_1500    0.428019    37
# 215                sport_count_2000    0.421379    38
# 98                     radiation_km    0.420844    39
# 75                    industrial_km    0.398916    40
# 269          culture_objects_top_25    0.392188    41
# 113                   workplaces_km    0.391608    42
# 92                     big_road2_km    0.387643    43
# 117                    preschool_km    0.386787    44
# 87                           ttk_km    0.377162    45
# 77                      cemetery_km    0.375661    46
# 112                   university_km    0.373383    47
# 154                 cafe_count_1000    0.370198    48
# 110           detention_facility_km    0.366983    49
# 72                        school_km    0.359064    50
# 120                       mosque_km    0.354293    51
# 23     culture_objects_top_25_raion    0.345868    52
# 125                  green_part_500    0.345044    53
# 162      cafe_count_1000_price_2500    0.317295    54
# 101                           ts_km    0.317011    55
# 85                         water_km    0.313193    56
# 218                  prom_part_3000    0.312609    57
# 106                     ice_rink_km    0.311388    58
# 164      cafe_count_1000_price_high    0.309177    59
# 12                  preschool_quota    0.308602    60
# 148                 green_part_1000    0.304853    61
# 99       power_transmission_line_km    0.304282    62
# 153                    trc_sqm_1000    0.300230    63
# 161      cafe_count_1000_price_1500    0.296313    64
# 68                    metro_km_avto    0.295475    65
# 252      cafe_count_5000_price_1000    0.293557    66
# 171                 green_part_1500    0.293545    67
# 118                   big_church_km    0.290717    68
# 124                     catering_km    0.287156    69
# 207      cafe_count_2000_price_1500    0.285250    70
# 97               nuclear_reactor_km    0.282102    71
# 36                       ekder_male    0.278241    72
# 131                  cafe_count_500    0.268446    73
# 67                   metro_min_avto    0.266890    74
# 73                          park_km    0.264709    75
# 103                  market_shop_km    0.258586    76
# 109               hospice_morgue_km    0.248842    77
# 95             bus_terminal_avto_km    0.246733    78
# 114             shopping_centers_km    0.244314    79
# 261                sport_count_5000    0.242578    80
# 149                  prom_part_1000    0.238078    81
# 30                       young_male    0.227640    82
# 91                     big_road1_km    0.227311    83
# 159       cafe_count_1000_price_500    0.225340    84
# 195                  prom_part_2000    0.223175    85
# 115                       office_km    0.222138    86
# 119             church_synagogue_km    0.220257    87
# 250        cafe_count_5000_na_price    0.218301    88
# 237              leisure_count_3000    0.215851    89
# 123                   exhibition_km    0.212895    90
# 228       cafe_count_3000_price_500    0.210560    91
# 225     cafe_sum_3000_max_price_avg    0.210263    92
# 242               office_count_5000    0.209360    93
# 243                 office_sqm_5000    0.208835    94
# 70                    metro_km_walk    0.207046    95
# 94               zd_vokzaly_avto_km    0.203081    96
# 203             cafe_avg_price_2000    0.200586    97
# 9                   green_zone_part    0.199824    98
# 241                  prom_part_5000    0.197860    99
# 38                          0_6_all    0.193952   100
# 202     cafe_sum_2000_max_price_avg    0.193706   101
# 133      cafe_sum_500_max_price_avg    0.193479   102
# 107                      stadium_km    0.192914   103
# 132      cafe_sum_500_min_price_avg    0.192753   104
# 82        railroad_station_avto_min    0.192306   105
# 251       cafe_count_5000_price_500    0.189424   106
# 222                    trc_sqm_3000    0.187664   107
# 221                  trc_count_3000    0.183805   108
# 108                   basketball_km    0.178262   109
# 185      cafe_count_1500_price_2500    0.174985   110
# 196               office_count_2000    0.172062   111
# 192                sport_count_1500    0.168294   112
# 179     cafe_sum_1500_max_price_avg    0.167135   113
# 102                   big_market_km    0.166797   114
# 176                    trc_sqm_1500    0.166159   115
# 227        cafe_count_3000_na_price    0.166112   116
# 15                     school_quota    0.165065   117
# 226             cafe_avg_price_3000    0.163722   118
# 16   school_education_centers_raion    0.163061   119
# 249             cafe_avg_price_5000    0.158944   120
# 232      cafe_count_3000_price_4000    0.157952   121
# 206      cafe_count_2000_price_1000    0.157298   122
# 265                        material    0.155990   123

# %%
# обучим модель на ** признаках
columns = df['feature'][0:best_count_feat]
temp_cat_feat = [x for x in cat_feat if x in columns.to_list()]
train_dataset = Pool(X_train[columns], y_train, cat_features=temp_cat_feat)  
best_model = CatBoostRegressor(iterations=best_iter)
best_model.fit(train_dataset, silent=True)
RMSLE = mean_squared_log_error(y_test, best_model.predict(X_test[columns]))**0.5
print(RMSLE)
# Out:
# 0.40755954496995905

# %% [markdown]
# Сохранение модели для выполнения задания школы DS

# %%
pkl_filename = "pickle_model.pkl" 
with open(pkl_filename, 'wb') as file:
    pickle.dump(best_model, file)

# %% [markdown]
# Для оценки модели на kagle, переобучим модель на неразделенной выборке train, и предскажем результаты по выборке test.

# %%
train_dataset = Pool(train[columns], target, cat_features=temp_cat_feat) 
best_model.fit(train_dataset)
RMSLE = mean_squared_log_error(target, best_model.predict(train[columns]))**0.5
print(RMSLE)
# Out:
# Learning rate set to 0.019775
# 0:	learn: 4732592.9581669	total: 50.3ms	remaining: 3m 59s
# 1:	learn: 4684965.9326350	total: 101ms	remaining: 4m
# 2:	learn: 4639133.8076010	total: 165ms	remaining: 4m 21s
# 3:	learn: 4594334.3589050	total: 228ms	remaining: 4m 31s
# 4:	learn: 4549746.6663299	total: 278ms	remaining: 4m 23s
# 5:	learn: 4507063.8649714	total: 332ms	remaining: 4m 22s
# 6:	learn: 4465021.6871645	total: 382ms	remaining: 4m 19s
# 7:	learn: 4422904.3187190	total: 430ms	remaining: 4m 14s
# 8:	learn: 4382339.2428655	total: 483ms	remaining: 4m 14s
# 9:	learn: 4342812.8820257	total: 534ms	remaining: 4m 13s
# 10:	learn: 4306636.3151813	total: 587ms	remaining: 4m 13s
# 11:	learn: 4270776.8153757	total: 640ms	remaining: 4m 12s
# 12:	learn: 4235068.7386874	total: 705ms	remaining: 4m 17s
# 13:	learn: 4201106.6562147	total: 756ms	remaining: 4m 16s
# 14:	learn: 4167134.9144163	total: 811ms	remaining: 4m 16s
# 15:	learn: 4132697.8251166	total: 868ms	remaining: 4m 17s
# 16:	learn: 4101177.1624477	total: 922ms	remaining: 4m 16s
# 17:	learn: 4069737.2523975	total: 978ms	remaining: 4m 17s
# 18:	learn: 4039306.3785488	total: 1.04s	remaining: 4m 18s
# 19:	learn: 4009091.7467088	total: 1.09s	remaining: 4m 17s
# 20:	learn: 3979640.5250174	total: 1.15s	remaining: 4m 19s
# 21:	learn: 3950907.3708456	total: 1.2s	remaining: 4m 18s
# 22:	learn: 3922674.3997614	total: 1.25s	remaining: 4m 17s
# 23:	learn: 3894934.8347925	total: 1.3s	remaining: 4m 16s
# 24:	learn: 3867754.5805799	total: 1.36s	remaining: 4m 16s
# 25:	learn: 3841166.8105252	total: 1.41s	remaining: 4m 17s
# 26:	learn: 3815984.0729402	total: 1.46s	remaining: 4m 16s
# 27:	learn: 3791979.0405036	total: 1.51s	remaining: 4m 15s
# 28:	learn: 3767730.1401632	total: 1.56s	remaining: 4m 14s
# 29:	learn: 3745081.0742937	total: 1.61s	remaining: 4m 13s
# 30:	learn: 3722486.5185831	total: 1.66s	remaining: 4m 13s
# 31:	learn: 3699153.7643436	total: 1.72s	remaining: 4m 13s
# 32:	learn: 3676755.6539992	total: 1.77s	remaining: 4m 13s
# 33:	learn: 3655018.8095574	total: 1.83s	remaining: 4m 13s
# 34:	learn: 3633662.3692350	total: 1.88s	remaining: 4m 13s
# 35:	learn: 3612547.6202081	total: 1.93s	remaining: 4m 13s
# 36:	learn: 3591486.6426881	total: 1.98s	remaining: 4m 12s
# 37:	learn: 3571797.7217221	total: 2.03s	remaining: 4m 12s
# 38:	learn: 3554480.7835928	total: 2.08s	remaining: 4m 11s
# 39:	learn: 3536428.6004648	total: 2.13s	remaining: 4m 11s
# 40:	learn: 3517581.0512716	total: 2.19s	remaining: 4m 11s
# 41:	learn: 3500043.7750043	total: 2.25s	remaining: 4m 12s
# 42:	learn: 3482655.5256086	total: 2.31s	remaining: 4m 12s
# 43:	learn: 3465595.9379782	total: 2.36s	remaining: 4m 12s
# 44:	learn: 3448129.0543514	total: 2.41s	remaining: 4m 12s
# 45:	learn: 3430937.0100680	total: 2.47s	remaining: 4m 12s
# 46:	learn: 3414921.5043731	total: 2.51s	remaining: 4m 11s
# 47:	learn: 3399455.0345312	total: 2.56s	remaining: 4m 11s
# 48:	learn: 3384565.0460943	total: 2.61s	remaining: 4m 10s
# 49:	learn: 3370300.7905136	total: 2.65s	remaining: 4m 9s
# 50:	learn: 3355310.3929047	total: 2.71s	remaining: 4m 10s
# 51:	learn: 3341219.6769350	total: 2.76s	remaining: 4m 9s
# 52:	learn: 3327276.6752790	total: 2.81s	remaining: 4m 9s
# 53:	learn: 3314998.3327491	total: 2.86s	remaining: 4m 9s
# 54:	learn: 3302058.5994781	total: 2.92s	remaining: 4m 9s
# 55:	learn: 3289005.2015606	total: 2.97s	remaining: 4m 9s
# 56:	learn: 3276488.1190324	total: 3.02s	remaining: 4m 9s
# 57:	learn: 3264957.7467612	total: 3.07s	remaining: 4m 8s
# 58:	learn: 3252381.8368854	total: 3.12s	remaining: 4m 8s
# 59:	learn: 3240457.0850645	total: 3.17s	remaining: 4m 8s
# 60:	learn: 3228439.7280759	total: 3.23s	remaining: 4m 8s
# 61:	learn: 3216694.0866006	total: 3.28s	remaining: 4m 8s
# 62:	learn: 3205371.4720552	total: 3.33s	remaining: 4m 8s
# 63:	learn: 3196249.0092112	total: 3.39s	remaining: 4m 8s
# 64:	learn: 3186302.0341249	total: 3.44s	remaining: 4m 8s
# 65:	learn: 3175073.0798842	total: 3.49s	remaining: 4m 7s
# 66:	learn: 3164967.0950146	total: 3.54s	remaining: 4m 7s
# 67:	learn: 3154973.5176405	total: 3.59s	remaining: 4m 7s
# 68:	learn: 3145498.5096097	total: 3.64s	remaining: 4m 6s
# 69:	learn: 3135879.7806648	total: 3.69s	remaining: 4m 6s
# 70:	learn: 3127792.4456877	total: 3.74s	remaining: 4m 6s
# 71:	learn: 3119046.1228228	total: 3.79s	remaining: 4m 6s
# 72:	learn: 3110172.9538534	total: 3.84s	remaining: 4m 6s
# 73:	learn: 3102322.8152855	total: 3.9s	remaining: 4m 6s
# 74:	learn: 3094321.0924490	total: 3.95s	remaining: 4m 6s
# 75:	learn: 3086785.2950079	total: 4s	remaining: 4m 6s
# 76:	learn: 3078464.3624225	total: 4.06s	remaining: 4m 6s
# 77:	learn: 3071306.7514751	total: 4.11s	remaining: 4m 6s
# 78:	learn: 3064197.0125509	total: 4.15s	remaining: 4m 5s
# 79:	learn: 3056436.4181843	total: 4.2s	remaining: 4m 5s
# 80:	learn: 3049226.8478773	total: 4.26s	remaining: 4m 5s
# 81:	learn: 3042791.5469297	total: 4.32s	remaining: 4m 6s
# 82:	learn: 3035458.9213962	total: 4.38s	remaining: 4m 6s
# 83:	learn: 3028296.8592274	total: 4.43s	remaining: 4m 6s
# 84:	learn: 3021197.9502829	total: 4.49s	remaining: 4m 6s
# 85:	learn: 3014887.8410642	total: 4.55s	remaining: 4m 6s
# 86:	learn: 3008405.7019373	total: 4.59s	remaining: 4m 6s
# 87:	learn: 3002143.9023782	total: 4.64s	remaining: 4m 6s
# 88:	learn: 2996411.5213382	total: 4.69s	remaining: 4m 5s
# 89:	learn: 2990575.0566751	total: 4.74s	remaining: 4m 5s
# 90:	learn: 2984725.2230904	total: 4.8s	remaining: 4m 6s
# 91:	learn: 2979114.7676499	total: 4.85s	remaining: 4m 5s
# 92:	learn: 2973240.6102182	total: 4.91s	remaining: 4m 5s
# 93:	learn: 2967591.8086358	total: 4.96s	remaining: 4m 5s
# 94:	learn: 2961334.8175722	total: 5.02s	remaining: 4m 6s
# 95:	learn: 2955578.1896665	total: 5.07s	remaining: 4m 6s
# 96:	learn: 2949711.0791005	total: 5.12s	remaining: 4m 5s
# 97:	learn: 2943953.0480168	total: 5.17s	remaining: 4m 5s
# 98:	learn: 2938494.5591294	total: 5.21s	remaining: 4m 5s
# 99:	learn: 2932183.7878142	total: 5.27s	remaining: 4m 5s
# 100:	learn: 2927436.0434700	total: 5.32s	remaining: 4m 5s
# 101:	learn: 2923168.4603352	total: 5.38s	remaining: 4m 5s
# 102:	learn: 2918280.3722212	total: 5.43s	remaining: 4m 5s
# 103:	learn: 2913035.8658838	total: 5.49s	remaining: 4m 5s
# 104:	learn: 2908374.2472543	total: 5.55s	remaining: 4m 5s
# 105:	learn: 2903859.9745847	total: 5.6s	remaining: 4m 5s
# 106:	learn: 2899604.3867750	total: 5.65s	remaining: 4m 5s
# 107:	learn: 2894785.0335767	total: 5.7s	remaining: 4m 5s
# 108:	learn: 2890141.8583906	total: 5.75s	remaining: 4m 5s
# 109:	learn: 2886108.1026254	total: 5.8s	remaining: 4m 4s
# 110:	learn: 2882006.0197705	total: 5.85s	remaining: 4m 4s
# 111:	learn: 2877449.4696437	total: 5.9s	remaining: 4m 4s
# 112:	learn: 2873293.9533912	total: 5.96s	remaining: 4m 4s
# 113:	learn: 2868052.9400848	total: 6.02s	remaining: 4m 5s
# 114:	learn: 2863919.7553470	total: 6.07s	remaining: 4m 4s
# 115:	learn: 2859800.3827899	total: 6.13s	remaining: 4m 5s
# 116:	learn: 2856379.4694159	total: 6.18s	remaining: 4m 5s
# 117:	learn: 2852187.6402348	total: 6.23s	remaining: 4m 4s
# 118:	learn: 2848922.9959751	total: 6.28s	remaining: 4m 4s
# 119:	learn: 2845870.0459033	total: 6.32s	remaining: 4m 4s
# 120:	learn: 2842412.9608833	total: 6.38s	remaining: 4m 4s
# 121:	learn: 2838556.5402911	total: 6.43s	remaining: 4m 4s
# 122:	learn: 2835443.9272063	total: 6.48s	remaining: 4m 3s
# 123:	learn: 2831703.5977868	total: 6.53s	remaining: 4m 3s
# 124:	learn: 2828029.7686542	total: 6.58s	remaining: 4m 3s
# 125:	learn: 2824321.5351292	total: 6.63s	remaining: 4m 3s
# 126:	learn: 2821025.6939004	total: 6.68s	remaining: 4m 3s
# 127:	learn: 2817601.9338121	total: 6.73s	remaining: 4m 3s
# 128:	learn: 2814158.6018195	total: 6.78s	remaining: 4m 3s
# 129:	learn: 2810754.3560029	total: 6.83s	remaining: 4m 3s
# 130:	learn: 2807436.0706676	total: 6.89s	remaining: 4m 3s
# 131:	learn: 2803212.2336528	total: 6.94s	remaining: 4m 3s
# 132:	learn: 2799814.2087891	total: 7s	remaining: 4m 3s
# 133:	learn: 2797217.1792398	total: 7.06s	remaining: 4m 3s
# 134:	learn: 2794068.4754090	total: 7.12s	remaining: 4m 3s
# 135:	learn: 2791255.9229934	total: 7.17s	remaining: 4m 3s
# 136:	learn: 2787955.0498057	total: 7.22s	remaining: 4m 3s
# 137:	learn: 2784427.3037251	total: 7.27s	remaining: 4m 3s
# 138:	learn: 2781573.7590241	total: 7.32s	remaining: 4m 3s
# 139:	learn: 2778966.7952887	total: 7.36s	remaining: 4m 2s
# 140:	learn: 2776186.9296088	total: 7.42s	remaining: 4m 2s
# 141:	learn: 2773468.8447673	total: 7.47s	remaining: 4m 2s
# 142:	learn: 2770047.7893122	total: 7.52s	remaining: 4m 2s
# 143:	learn: 2766522.1119563	total: 7.58s	remaining: 4m 2s
# 144:	learn: 2763521.2205945	total: 7.64s	remaining: 4m 3s
# 145:	learn: 2760627.0096185	total: 7.7s	remaining: 4m 3s
# 146:	learn: 2757502.0237422	total: 7.74s	remaining: 4m 2s
# 147:	learn: 2754981.3513102	total: 7.79s	remaining: 4m 2s
# 148:	learn: 2752312.5923009	total: 7.84s	remaining: 4m 2s
# 149:	learn: 2749800.5540673	total: 7.9s	remaining: 4m 2s
# 150:	learn: 2746890.8452047	total: 7.96s	remaining: 4m 2s
# 151:	learn: 2743400.3850852	total: 8.01s	remaining: 4m 2s
# 152:	learn: 2740803.4649844	total: 8.06s	remaining: 4m 2s
# 153:	learn: 2738335.4475212	total: 8.12s	remaining: 4m 2s
# 154:	learn: 2735797.5963647	total: 8.18s	remaining: 4m 2s
# 155:	learn: 2732693.2176283	total: 8.24s	remaining: 4m 2s
# 156:	learn: 2730254.5023583	total: 8.29s	remaining: 4m 2s
# 157:	learn: 2728233.2897130	total: 8.34s	remaining: 4m 2s
# 158:	learn: 2726106.8849548	total: 8.38s	remaining: 4m 2s
# 159:	learn: 2724014.3267546	total: 8.43s	remaining: 4m 2s
# 160:	learn: 2722229.2675055	total: 8.49s	remaining: 4m 2s
# 161:	learn: 2719816.6019242	total: 8.54s	remaining: 4m 2s
# 162:	learn: 2717012.8417240	total: 8.59s	remaining: 4m 2s
# 163:	learn: 2715210.4801733	total: 8.64s	remaining: 4m 1s
# 164:	learn: 2712957.5762546	total: 8.69s	remaining: 4m 1s
# 165:	learn: 2711021.8870267	total: 8.75s	remaining: 4m 1s
# 166:	learn: 2709256.2699878	total: 8.8s	remaining: 4m 1s
# 167:	learn: 2707202.1176129	total: 8.85s	remaining: 4m 1s
# 168:	learn: 2705190.2958262	total: 8.9s	remaining: 4m 1s
# 169:	learn: 2702578.2530102	total: 8.95s	remaining: 4m 1s
# 170:	learn: 2700546.4551456	total: 9s	remaining: 4m 1s
# 171:	learn: 2698462.9166292	total: 9.04s	remaining: 4m 1s
# 172:	learn: 2696175.7150769	total: 9.1s	remaining: 4m
# 173:	learn: 2693938.2848429	total: 9.15s	remaining: 4m
# 174:	learn: 2692581.8858762	total: 9.21s	remaining: 4m 1s
# 175:	learn: 2690565.0050636	total: 9.27s	remaining: 4m 1s
# 176:	learn: 2688973.6215576	total: 9.31s	remaining: 4m
# 177:	learn: 2687332.5005809	total: 9.37s	remaining: 4m
# 178:	learn: 2685067.3733372	total: 9.41s	remaining: 4m
# 179:	learn: 2683177.6458622	total: 9.45s	remaining: 4m
# 180:	learn: 2681146.9621411	total: 9.5s	remaining: 4m
# 181:	learn: 2679464.2161070	total: 9.54s	remaining: 3m 59s
# 182:	learn: 2678048.8644008	total: 9.6s	remaining: 3m 59s
# 183:	learn: 2676366.5485612	total: 9.64s	remaining: 3m 59s
# 184:	learn: 2674203.1248303	total: 9.7s	remaining: 3m 59s
# 185:	learn: 2672105.2873351	total: 9.76s	remaining: 3m 59s
# 186:	learn: 2670603.4819927	total: 9.81s	remaining: 3m 59s
# 187:	learn: 2668552.1553747	total: 9.86s	remaining: 3m 59s
# 188:	learn: 2667478.0391486	total: 9.93s	remaining: 3m 59s
# 189:	learn: 2665656.6281031	total: 9.98s	remaining: 3m 59s
# 190:	learn: 2664165.6909082	total: 10s	remaining: 3m 59s
# 191:	learn: 2662720.0994725	total: 10.1s	remaining: 3m 59s
# 192:	learn: 2661593.4866673	total: 10.1s	remaining: 3m 59s
# 193:	learn: 2659649.0619813	total: 10.2s	remaining: 3m 59s
# 194:	learn: 2658087.9530825	total: 10.2s	remaining: 3m 59s
# 195:	learn: 2656473.4574232	total: 10.3s	remaining: 3m 59s
# 196:	learn: 2655260.2944708	total: 10.3s	remaining: 3m 59s
# 197:	learn: 2654046.8577834	total: 10.4s	remaining: 3m 59s
# 198:	learn: 2651443.5548988	total: 10.4s	remaining: 3m 59s
# 199:	learn: 2650031.0371125	total: 10.5s	remaining: 3m 58s
# 200:	learn: 2648648.7648672	total: 10.5s	remaining: 3m 58s
# 201:	learn: 2647338.4011065	total: 10.6s	remaining: 3m 58s
# 202:	learn: 2645836.1048100	total: 10.6s	remaining: 3m 58s
# 203:	learn: 2643877.9550553	total: 10.7s	remaining: 3m 58s
# 204:	learn: 2642298.2662182	total: 10.7s	remaining: 3m 58s
# 205:	learn: 2640897.0929439	total: 10.8s	remaining: 3m 58s
# 206:	learn: 2639221.2741148	total: 10.8s	remaining: 3m 58s
# 207:	learn: 2637773.4611189	total: 10.9s	remaining: 3m 58s
# 208:	learn: 2636737.2763270	total: 10.9s	remaining: 3m 58s
# 209:	learn: 2635194.7323734	total: 11s	remaining: 3m 58s
# 210:	learn: 2633862.8576048	total: 11.1s	remaining: 3m 58s
# 211:	learn: 2631795.1028427	total: 11.1s	remaining: 3m 57s
# 212:	learn: 2630408.6778660	total: 11.2s	remaining: 3m 57s
# 213:	learn: 2628794.1836871	total: 11.2s	remaining: 3m 57s
# 214:	learn: 2627826.7230253	total: 11.3s	remaining: 3m 57s
# 215:	learn: 2626747.5840413	total: 11.3s	remaining: 3m 57s
# 216:	learn: 2625628.0303906	total: 11.4s	remaining: 3m 57s
# 217:	learn: 2624077.7553956	total: 11.4s	remaining: 3m 57s
# 218:	learn: 2622733.6924028	total: 11.5s	remaining: 3m 57s
# 219:	learn: 2620304.9793257	total: 11.5s	remaining: 3m 57s
# 220:	learn: 2618945.9695211	total: 11.6s	remaining: 3m 57s
# 221:	learn: 2617521.2371333	total: 11.6s	remaining: 3m 57s
# 222:	learn: 2616865.0469829	total: 11.7s	remaining: 3m 56s
# 223:	learn: 2615362.8826577	total: 11.7s	remaining: 3m 56s
# 224:	learn: 2613613.2148149	total: 11.7s	remaining: 3m 56s
# 225:	learn: 2612470.3165285	total: 11.8s	remaining: 3m 56s
# 226:	learn: 2609758.7883367	total: 11.9s	remaining: 3m 56s
# 227:	learn: 2608628.1623725	total: 11.9s	remaining: 3m 57s
# 228:	learn: 2607430.4711790	total: 12s	remaining: 3m 57s
# 229:	learn: 2605968.7351527	total: 12.1s	remaining: 3m 57s
# 230:	learn: 2604320.5454643	total: 12.1s	remaining: 3m 57s
# 231:	learn: 2603264.9846332	total: 12.2s	remaining: 3m 57s
# 232:	learn: 2602004.3800787	total: 12.2s	remaining: 3m 57s
# 233:	learn: 2600634.4759965	total: 12.3s	remaining: 3m 57s
# 234:	learn: 2599279.4867710	total: 12.3s	remaining: 3m 57s
# 235:	learn: 2598186.5426368	total: 12.4s	remaining: 3m 57s
# 236:	learn: 2596704.3183941	total: 12.4s	remaining: 3m 57s
# 237:	learn: 2595155.7229969	total: 12.5s	remaining: 3m 56s
# 238:	learn: 2594041.1046050	total: 12.5s	remaining: 3m 56s
# 239:	learn: 2593415.3768679	total: 12.6s	remaining: 3m 56s
# 240:	learn: 2592047.1845296	total: 12.6s	remaining: 3m 56s
# 241:	learn: 2590876.0704042	total: 12.7s	remaining: 3m 56s
# 242:	learn: 2589913.4253558	total: 12.7s	remaining: 3m 56s
# 243:	learn: 2588657.1186209	total: 12.8s	remaining: 3m 56s
# 244:	learn: 2587596.3352346	total: 12.8s	remaining: 3m 56s
# 245:	learn: 2586391.6806991	total: 12.9s	remaining: 3m 56s
# 246:	learn: 2584712.2296869	total: 12.9s	remaining: 3m 56s
# 247:	learn: 2583441.0097310	total: 13s	remaining: 3m 55s
# 248:	learn: 2582551.9092929	total: 13s	remaining: 3m 55s
# 249:	learn: 2581643.6159399	total: 13.1s	remaining: 3m 55s
# 250:	learn: 2580446.3505950	total: 13.1s	remaining: 3m 55s
# 251:	learn: 2579326.7232844	total: 13.2s	remaining: 3m 55s
# 252:	learn: 2578370.6612157	total: 13.2s	remaining: 3m 55s
# 253:	learn: 2577603.4036155	total: 13.3s	remaining: 3m 55s
# 254:	learn: 2576757.7692264	total: 13.3s	remaining: 3m 55s
# 255:	learn: 2576064.4760085	total: 13.4s	remaining: 3m 55s
# 256:	learn: 2574632.7191322	total: 13.4s	remaining: 3m 55s
# 257:	learn: 2573300.0408144	total: 13.5s	remaining: 3m 55s
# 258:	learn: 2572533.2113886	total: 13.5s	remaining: 3m 54s
# 259:	learn: 2571494.4413440	total: 13.6s	remaining: 3m 54s
# 260:	learn: 2570629.3714470	total: 13.6s	remaining: 3m 54s
# 261:	learn: 2569731.8850731	total: 13.7s	remaining: 3m 54s
# 262:	learn: 2568797.1091753	total: 13.7s	remaining: 3m 54s
# 263:	learn: 2567885.5842869	total: 13.8s	remaining: 3m 54s
# 264:	learn: 2566390.1569665	total: 13.8s	remaining: 3m 54s
# 265:	learn: 2565182.3066199	total: 13.9s	remaining: 3m 54s
# 266:	learn: 2563903.0188588	total: 13.9s	remaining: 3m 54s
# 267:	learn: 2562700.8481831	total: 14s	remaining: 3m 54s
# 268:	learn: 2561553.9360171	total: 14s	remaining: 3m 54s
# 269:	learn: 2560456.0153224	total: 14.1s	remaining: 3m 53s
# 270:	learn: 2559606.0658600	total: 14.1s	remaining: 3m 54s
# 271:	learn: 2558910.8059591	total: 14.2s	remaining: 3m 53s
# 272:	learn: 2557653.1731226	total: 14.2s	remaining: 3m 53s
# 273:	learn: 2556774.9701272	total: 14.3s	remaining: 3m 53s
# 274:	learn: 2556049.0445794	total: 14.3s	remaining: 3m 53s
# 275:	learn: 2555110.9515259	total: 14.4s	remaining: 3m 53s
# 276:	learn: 2554084.5609008	total: 14.4s	remaining: 3m 53s
# 277:	learn: 2553117.2505190	total: 14.5s	remaining: 3m 53s
# 278:	learn: 2552070.6342977	total: 14.5s	remaining: 3m 53s
# 279:	learn: 2550952.4739194	total: 14.6s	remaining: 3m 52s
# 280:	learn: 2549815.0627183	total: 14.6s	remaining: 3m 52s
# 281:	learn: 2548815.3864154	total: 14.7s	remaining: 3m 52s
# 282:	learn: 2548245.7867271	total: 14.7s	remaining: 3m 52s
# 283:	learn: 2547787.4944334	total: 14.8s	remaining: 3m 52s
# 284:	learn: 2547039.3145016	total: 14.8s	remaining: 3m 52s
# 285:	learn: 2546017.7463679	total: 14.9s	remaining: 3m 52s
# 286:	learn: 2545096.5707801	total: 14.9s	remaining: 3m 52s
# 287:	learn: 2543921.4874092	total: 15s	remaining: 3m 52s
# 288:	learn: 2543208.2647216	total: 15s	remaining: 3m 52s
# 289:	learn: 2542575.4644158	total: 15.1s	remaining: 3m 52s
# 290:	learn: 2541868.3482113	total: 15.1s	remaining: 3m 51s
# 291:	learn: 2540810.1683942	total: 15.2s	remaining: 3m 51s
# 292:	learn: 2539956.3116058	total: 15.2s	remaining: 3m 51s
# 293:	learn: 2539236.4315912	total: 15.3s	remaining: 3m 51s
# 294:	learn: 2538594.8957475	total: 15.3s	remaining: 3m 51s
# 295:	learn: 2538065.9491029	total: 15.4s	remaining: 3m 51s
# 296:	learn: 2537302.9128068	total: 15.4s	remaining: 3m 51s
# 297:	learn: 2536044.5718816	total: 15.4s	remaining: 3m 51s
# 298:	learn: 2535610.8362097	total: 15.5s	remaining: 3m 50s
# 299:	learn: 2534830.4010428	total: 15.5s	remaining: 3m 50s
# 300:	learn: 2533833.2834596	total: 15.6s	remaining: 3m 50s
# 301:	learn: 2532502.3025688	total: 15.7s	remaining: 3m 50s
# 302:	learn: 2531915.0120396	total: 15.7s	remaining: 3m 50s
# 303:	learn: 2530934.3384941	total: 15.8s	remaining: 3m 50s
# 304:	learn: 2529793.9309150	total: 15.8s	remaining: 3m 50s
# 305:	learn: 2529332.1235295	total: 15.8s	remaining: 3m 50s
# 306:	learn: 2528481.1040921	total: 15.9s	remaining: 3m 50s
# 307:	learn: 2527499.4459917	total: 15.9s	remaining: 3m 50s
# 308:	learn: 2526919.5226394	total: 16s	remaining: 3m 50s
# 309:	learn: 2526131.7422098	total: 16.1s	remaining: 3m 50s
# 310:	learn: 2525390.1713247	total: 16.1s	remaining: 3m 50s
# 311:	learn: 2524749.0172766	total: 16.2s	remaining: 3m 50s
# 312:	learn: 2524334.5593897	total: 16.2s	remaining: 3m 50s
# 313:	learn: 2523023.1581661	total: 16.3s	remaining: 3m 50s
# 314:	learn: 2522352.7464690	total: 16.3s	remaining: 3m 49s
# 315:	learn: 2521397.4979017	total: 16.4s	remaining: 3m 49s
# 316:	learn: 2520765.1122979	total: 16.4s	remaining: 3m 49s
# 317:	learn: 2519969.2131306	total: 16.5s	remaining: 3m 49s
# 318:	learn: 2519367.5728518	total: 16.5s	remaining: 3m 49s
# 319:	learn: 2518530.4893143	total: 16.5s	remaining: 3m 49s
# 320:	learn: 2517526.4937552	total: 16.6s	remaining: 3m 49s
# 321:	learn: 2516411.0127437	total: 16.7s	remaining: 3m 49s
# 322:	learn: 2515700.7916966	total: 16.7s	remaining: 3m 49s
# 323:	learn: 2514922.1982393	total: 16.8s	remaining: 3m 49s
# 324:	learn: 2513987.3032022	total: 16.8s	remaining: 3m 49s
# 325:	learn: 2513134.1993109	total: 16.9s	remaining: 3m 49s
# 326:	learn: 2512623.6385955	total: 16.9s	remaining: 3m 48s
# 327:	learn: 2512025.6327107	total: 17s	remaining: 3m 48s
# 328:	learn: 2511397.9764856	total: 17s	remaining: 3m 48s
# 329:	learn: 2510356.1207929	total: 17.1s	remaining: 3m 48s
# 330:	learn: 2509862.8338745	total: 17.1s	remaining: 3m 48s
# 331:	learn: 2509040.1810363	total: 17.1s	remaining: 3m 48s
# 332:	learn: 2508456.5456179	total: 17.2s	remaining: 3m 48s
# 333:	learn: 2507658.6860920	total: 17.3s	remaining: 3m 48s
# 334:	learn: 2506973.4872792	total: 17.3s	remaining: 3m 48s
# 335:	learn: 2506599.8548582	total: 17.4s	remaining: 3m 48s
# 336:	learn: 2505808.4553951	total: 17.4s	remaining: 3m 48s
# 337:	learn: 2505186.9491346	total: 17.4s	remaining: 3m 48s
# 338:	learn: 2504739.3604079	total: 17.5s	remaining: 3m 47s
# 339:	learn: 2504146.3319200	total: 17.5s	remaining: 3m 47s
# 340:	learn: 2503186.4887188	total: 17.6s	remaining: 3m 47s
# 341:	learn: 2502508.4323785	total: 17.6s	remaining: 3m 47s
# 342:	learn: 2501842.5534857	total: 17.7s	remaining: 3m 47s
# 343:	learn: 2500925.4364479	total: 17.7s	remaining: 3m 47s
# 344:	learn: 2500157.3945360	total: 17.8s	remaining: 3m 47s
# 345:	learn: 2499622.2946691	total: 17.8s	remaining: 3m 47s
# 346:	learn: 2499145.2096513	total: 17.9s	remaining: 3m 47s
# 347:	learn: 2498057.6775078	total: 17.9s	remaining: 3m 47s
# 348:	learn: 2497766.1623292	total: 18s	remaining: 3m 47s
# 349:	learn: 2497270.8102893	total: 18s	remaining: 3m 46s
# 350:	learn: 2496411.3232560	total: 18.1s	remaining: 3m 46s
# 351:	learn: 2495387.7658595	total: 18.1s	remaining: 3m 46s
# 352:	learn: 2494234.1903586	total: 18.2s	remaining: 3m 46s
# 353:	learn: 2493414.3985444	total: 18.2s	remaining: 3m 46s
# 354:	learn: 2492368.4832076	total: 18.3s	remaining: 3m 46s
# 355:	learn: 2491186.3346678	total: 18.3s	remaining: 3m 46s
# 356:	learn: 2490825.7449988	total: 18.4s	remaining: 3m 46s
# 357:	learn: 2490153.6273980	total: 18.4s	remaining: 3m 46s
# 358:	learn: 2488969.2459555	total: 18.5s	remaining: 3m 46s
# 359:	learn: 2488016.8715902	total: 18.5s	remaining: 3m 46s
# 360:	learn: 2487563.8691010	total: 18.6s	remaining: 3m 46s
# 361:	learn: 2487063.4559914	total: 18.6s	remaining: 3m 46s
# 362:	learn: 2486034.8639611	total: 18.7s	remaining: 3m 45s
# 363:	learn: 2485453.2420100	total: 18.7s	remaining: 3m 45s
# 364:	learn: 2484717.5327963	total: 18.8s	remaining: 3m 45s
# 365:	learn: 2483518.5453187	total: 18.8s	remaining: 3m 45s
# 366:	learn: 2482630.7151559	total: 18.9s	remaining: 3m 45s
# 367:	learn: 2481990.0865820	total: 18.9s	remaining: 3m 45s
# 368:	learn: 2481407.6280480	total: 19s	remaining: 3m 45s
# 369:	learn: 2479953.8630256	total: 19s	remaining: 3m 45s
# 370:	learn: 2479547.1304750	total: 19.1s	remaining: 3m 45s
# 371:	learn: 2478860.6753145	total: 19.1s	remaining: 3m 45s
# 372:	learn: 2478276.6627983	total: 19.2s	remaining: 3m 45s
# 373:	learn: 2477430.6180951	total: 19.2s	remaining: 3m 45s
# 374:	learn: 2476798.9462559	total: 19.3s	remaining: 3m 45s
# 375:	learn: 2476243.7522723	total: 19.3s	remaining: 3m 45s
# 376:	learn: 2475769.5988475	total: 19.4s	remaining: 3m 45s
# 377:	learn: 2475265.7534777	total: 19.4s	remaining: 3m 44s
# 378:	learn: 2474124.2474310	total: 19.5s	remaining: 3m 44s
# 379:	learn: 2473524.9602122	total: 19.5s	remaining: 3m 44s
# 380:	learn: 2472950.5561149	total: 19.6s	remaining: 3m 44s
# 381:	learn: 2472590.5617677	total: 19.6s	remaining: 3m 44s
# 382:	learn: 2471751.7032648	total: 19.7s	remaining: 3m 44s
# 383:	learn: 2470945.1198824	total: 19.7s	remaining: 3m 44s
# 384:	learn: 2469941.4195251	total: 19.8s	remaining: 3m 44s
# 385:	learn: 2469144.6671425	total: 19.8s	remaining: 3m 44s
# 386:	learn: 2468098.6363572	total: 19.9s	remaining: 3m 44s
# 387:	learn: 2467488.2291771	total: 19.9s	remaining: 3m 44s
# 388:	learn: 2466522.5442366	total: 20s	remaining: 3m 44s
# 389:	learn: 2466079.5551638	total: 20s	remaining: 3m 43s
# 390:	learn: 2465175.6808536	total: 20.1s	remaining: 3m 43s
# 391:	learn: 2464017.2506834	total: 20.1s	remaining: 3m 43s
# 392:	learn: 2463392.9397444	total: 20.2s	remaining: 3m 43s
# 393:	learn: 2462919.1618051	total: 20.2s	remaining: 3m 43s
# 394:	learn: 2462367.4577148	total: 20.2s	remaining: 3m 43s
# 395:	learn: 2462143.1111390	total: 20.3s	remaining: 3m 43s
# 396:	learn: 2461685.6166107	total: 20.4s	remaining: 3m 43s
# 397:	learn: 2461016.1719376	total: 20.4s	remaining: 3m 43s
# 398:	learn: 2460621.5777246	total: 20.5s	remaining: 3m 43s
# 399:	learn: 2460000.5371156	total: 20.5s	remaining: 3m 43s
# 400:	learn: 2459331.6916709	total: 20.6s	remaining: 3m 43s
# 401:	learn: 2458993.4037117	total: 20.6s	remaining: 3m 43s
# 402:	learn: 2458308.3462836	total: 20.6s	remaining: 3m 42s
# 403:	learn: 2457173.8955218	total: 20.7s	remaining: 3m 42s
# 404:	learn: 2456671.6961348	total: 20.7s	remaining: 3m 42s
# 405:	learn: 2456260.8982402	total: 20.8s	remaining: 3m 42s
# 406:	learn: 2455859.4010385	total: 20.8s	remaining: 3m 42s
# 407:	learn: 2455246.4681096	total: 20.9s	remaining: 3m 42s
# 408:	learn: 2454942.9989164	total: 21s	remaining: 3m 42s
# 409:	learn: 2453853.9843618	total: 21s	remaining: 3m 42s
# 410:	learn: 2453191.1046440	total: 21.1s	remaining: 3m 42s
# 411:	learn: 2452373.6513607	total: 21.1s	remaining: 3m 42s
# 412:	learn: 2451654.6329889	total: 21.2s	remaining: 3m 42s
# 413:	learn: 2450965.3613473	total: 21.2s	remaining: 3m 42s
# 414:	learn: 2450290.9514178	total: 21.3s	remaining: 3m 42s
# 415:	learn: 2449999.0179469	total: 21.3s	remaining: 3m 42s
# 416:	learn: 2449595.8766852	total: 21.4s	remaining: 3m 42s
# 417:	learn: 2449160.6197463	total: 21.4s	remaining: 3m 42s
# 418:	learn: 2448826.9387712	total: 21.5s	remaining: 3m 42s
# 419:	learn: 2448446.6880412	total: 21.5s	remaining: 3m 42s
# 420:	learn: 2447658.9730228	total: 21.6s	remaining: 3m 42s
# 421:	learn: 2447297.3826433	total: 21.6s	remaining: 3m 41s
# 422:	learn: 2446924.8710642	total: 21.7s	remaining: 3m 41s
# 423:	learn: 2446509.4195323	total: 21.7s	remaining: 3m 41s
# 424:	learn: 2445623.7495453	total: 21.8s	remaining: 3m 41s
# 425:	learn: 2444817.5997141	total: 21.8s	remaining: 3m 41s
# 426:	learn: 2444560.5654899	total: 21.9s	remaining: 3m 41s
# 427:	learn: 2444257.2940610	total: 21.9s	remaining: 3m 41s
# 428:	learn: 2443697.8133870	total: 22s	remaining: 3m 41s
# 429:	learn: 2443075.6406963	total: 22s	remaining: 3m 41s
# 430:	learn: 2442611.0418299	total: 22.1s	remaining: 3m 41s
# 431:	learn: 2442086.3603058	total: 22.2s	remaining: 3m 41s
# 432:	learn: 2441902.0763460	total: 22.2s	remaining: 3m 41s
# 433:	learn: 2441700.2204142	total: 22.3s	remaining: 3m 41s
# 434:	learn: 2441278.4297650	total: 22.3s	remaining: 3m 41s
# 435:	learn: 2440821.6574904	total: 22.4s	remaining: 3m 41s
# 436:	learn: 2440449.8549713	total: 22.4s	remaining: 3m 41s
# 437:	learn: 2440016.9221152	total: 22.5s	remaining: 3m 41s
# 438:	learn: 2439574.6184070	total: 22.5s	remaining: 3m 41s
# 439:	learn: 2438992.5278425	total: 22.6s	remaining: 3m 41s
# 440:	learn: 2438535.8286308	total: 22.6s	remaining: 3m 41s
# 441:	learn: 2437755.9269188	total: 22.7s	remaining: 3m 41s
# 442:	learn: 2437294.1267180	total: 22.7s	remaining: 3m 41s
# 443:	learn: 2437093.2508578	total: 22.8s	remaining: 3m 41s
# 444:	learn: 2436732.0206446	total: 22.8s	remaining: 3m 41s
# 445:	learn: 2436379.4092964	total: 22.9s	remaining: 3m 41s
# 446:	learn: 2435885.0631577	total: 22.9s	remaining: 3m 41s
# 447:	learn: 2434951.9550703	total: 23s	remaining: 3m 41s
# 448:	learn: 2434531.5299228	total: 23.1s	remaining: 3m 41s
# 449:	learn: 2433990.8777536	total: 23.1s	remaining: 3m 41s
# 450:	learn: 2433683.9791187	total: 23.2s	remaining: 3m 40s
# 451:	learn: 2433252.1302491	total: 23.2s	remaining: 3m 40s
# 452:	learn: 2432944.8590618	total: 23.2s	remaining: 3m 40s
# 453:	learn: 2432350.1573448	total: 23.3s	remaining: 3m 40s
# 454:	learn: 2432110.0067384	total: 23.4s	remaining: 3m 40s
# 455:	learn: 2431508.7803913	total: 23.4s	remaining: 3m 40s
# 456:	learn: 2431140.2465598	total: 23.5s	remaining: 3m 40s
# 457:	learn: 2430778.7900507	total: 23.5s	remaining: 3m 40s
# 458:	learn: 2430458.8427106	total: 23.6s	remaining: 3m 40s
# 459:	learn: 2430025.7597331	total: 23.6s	remaining: 3m 40s
# 460:	learn: 2429248.4086557	total: 23.7s	remaining: 3m 40s
# 461:	learn: 2429004.8628035	total: 23.7s	remaining: 3m 40s
# 462:	learn: 2428406.7370294	total: 23.8s	remaining: 3m 40s
# 463:	learn: 2427870.3779415	total: 23.8s	remaining: 3m 40s
# 464:	learn: 2427396.2165168	total: 23.9s	remaining: 3m 40s
# 465:	learn: 2427082.7437916	total: 23.9s	remaining: 3m 40s
# 466:	learn: 2426731.7862207	total: 24s	remaining: 3m 40s
# 467:	learn: 2426416.2352018	total: 24s	remaining: 3m 39s
# 468:	learn: 2426244.2651263	total: 24.1s	remaining: 3m 39s
# 469:	learn: 2425810.1242536	total: 24.1s	remaining: 3m 39s
# 470:	learn: 2425147.6666534	total: 24.2s	remaining: 3m 39s
# 471:	learn: 2424730.1470433	total: 24.2s	remaining: 3m 39s
# 472:	learn: 2423902.7523462	total: 24.3s	remaining: 3m 39s
# 473:	learn: 2423237.1549396	total: 24.3s	remaining: 3m 39s
# 474:	learn: 2422550.2796119	total: 24.4s	remaining: 3m 39s
# 475:	learn: 2421400.9352709	total: 24.4s	remaining: 3m 39s
# 476:	learn: 2420745.6458413	total: 24.5s	remaining: 3m 39s
# 477:	learn: 2420679.0845237	total: 24.5s	remaining: 3m 39s
# 478:	learn: 2419915.5755653	total: 24.6s	remaining: 3m 39s
# 479:	learn: 2419004.8660690	total: 24.6s	remaining: 3m 39s
# 480:	learn: 2418440.6289433	total: 24.7s	remaining: 3m 39s
# 481:	learn: 2418210.0617269	total: 24.7s	remaining: 3m 39s
# 482:	learn: 2417556.7091875	total: 24.8s	remaining: 3m 39s
# 483:	learn: 2417151.0111310	total: 24.8s	remaining: 3m 39s
# 484:	learn: 2416759.9133625	total: 24.9s	remaining: 3m 38s
# 485:	learn: 2416317.7022633	total: 24.9s	remaining: 3m 38s
# 486:	learn: 2416123.5951582	total: 25s	remaining: 3m 38s
# 487:	learn: 2415737.8955734	total: 25s	remaining: 3m 38s
# 488:	learn: 2415543.3615066	total: 25.1s	remaining: 3m 38s
# 489:	learn: 2414631.1792618	total: 25.1s	remaining: 3m 38s
# 490:	learn: 2413829.9026638	total: 25.2s	remaining: 3m 38s
# 491:	learn: 2413465.7631001	total: 25.2s	remaining: 3m 38s
# 492:	learn: 2412607.4319221	total: 25.3s	remaining: 3m 38s
# 493:	learn: 2412422.1979873	total: 25.3s	remaining: 3m 38s
# 494:	learn: 2411926.3283643	total: 25.4s	remaining: 3m 38s
# 495:	learn: 2411767.5363521	total: 25.4s	remaining: 3m 38s
# 496:	learn: 2411166.8163682	total: 25.5s	remaining: 3m 38s
# 497:	learn: 2410281.0313756	total: 25.5s	remaining: 3m 38s
# 498:	learn: 2409711.6262465	total: 25.6s	remaining: 3m 38s
# 499:	learn: 2409069.8256657	total: 25.6s	remaining: 3m 38s
# 500:	learn: 2408400.6021625	total: 25.7s	remaining: 3m 38s
# 501:	learn: 2407832.6765271	total: 25.7s	remaining: 3m 38s
# 502:	learn: 2407215.1362557	total: 25.8s	remaining: 3m 37s
# 503:	learn: 2406985.3364783	total: 25.8s	remaining: 3m 37s
# 504:	learn: 2405932.7420250	total: 25.9s	remaining: 3m 37s
# 505:	learn: 2405095.9596170	total: 25.9s	remaining: 3m 37s
# 506:	learn: 2404620.9851869	total: 26s	remaining: 3m 37s
# 507:	learn: 2403904.0918531	total: 26s	remaining: 3m 37s
# 508:	learn: 2403456.4255321	total: 26.1s	remaining: 3m 37s
# 509:	learn: 2403074.8564237	total: 26.1s	remaining: 3m 37s
# 510:	learn: 2402685.5644490	total: 26.2s	remaining: 3m 37s
# 511:	learn: 2401439.1708072	total: 26.2s	remaining: 3m 37s
# 512:	learn: 2400644.5432124	total: 26.3s	remaining: 3m 37s
# 513:	learn: 2399777.2071810	total: 26.3s	remaining: 3m 37s
# 514:	learn: 2398810.9254890	total: 26.4s	remaining: 3m 37s
# 515:	learn: 2398075.4565112	total: 26.5s	remaining: 3m 37s
# 516:	learn: 2397479.6722088	total: 26.5s	remaining: 3m 37s
# 517:	learn: 2396358.1547169	total: 26.6s	remaining: 3m 37s
# 518:	learn: 2395461.9666108	total: 26.6s	remaining: 3m 37s
# 519:	learn: 2394899.9936658	total: 26.7s	remaining: 3m 37s
# 520:	learn: 2394493.3329900	total: 26.7s	remaining: 3m 37s
# 521:	learn: 2394013.9703427	total: 26.8s	remaining: 3m 37s
# 522:	learn: 2393666.4571659	total: 26.8s	remaining: 3m 37s
# 523:	learn: 2393380.2092235	total: 26.9s	remaining: 3m 37s
# 524:	learn: 2393015.2615950	total: 26.9s	remaining: 3m 36s
# 525:	learn: 2392888.8303533	total: 27s	remaining: 3m 36s
# 526:	learn: 2392523.0407422	total: 27s	remaining: 3m 36s
# 527:	learn: 2392092.4059590	total: 27.1s	remaining: 3m 36s
# 528:	learn: 2391592.1268739	total: 27.1s	remaining: 3m 36s
# 529:	learn: 2391285.1395016	total: 27.2s	remaining: 3m 36s
# 530:	learn: 2390849.3275089	total: 27.2s	remaining: 3m 36s
# 531:	learn: 2390656.2489681	total: 27.3s	remaining: 3m 36s
# 532:	learn: 2390596.2095231	total: 27.4s	remaining: 3m 36s
# 533:	learn: 2389898.0466654	total: 27.4s	remaining: 3m 36s
# 534:	learn: 2389242.1338550	total: 27.5s	remaining: 3m 36s
# 535:	learn: 2388601.2186597	total: 27.5s	remaining: 3m 36s
# 536:	learn: 2388167.6929738	total: 27.6s	remaining: 3m 36s
# 537:	learn: 2387602.8088141	total: 27.6s	remaining: 3m 36s
# 538:	learn: 2387567.3011417	total: 27.7s	remaining: 3m 36s
# 539:	learn: 2387363.3116144	total: 27.7s	remaining: 3m 36s
# 540:	learn: 2387224.7972103	total: 27.8s	remaining: 3m 36s
# 541:	learn: 2386572.7774736	total: 27.8s	remaining: 3m 36s
# 542:	learn: 2385997.3567031	total: 27.9s	remaining: 3m 36s
# 543:	learn: 2385455.3454487	total: 27.9s	remaining: 3m 36s
# 544:	learn: 2384747.6932271	total: 28s	remaining: 3m 36s
# 545:	learn: 2384267.1034833	total: 28s	remaining: 3m 36s
# 546:	learn: 2383966.6969574	total: 28.1s	remaining: 3m 35s
# 547:	learn: 2383895.2009290	total: 28.1s	remaining: 3m 35s
# 548:	learn: 2383624.8982221	total: 28.2s	remaining: 3m 35s
# 549:	learn: 2383320.6676203	total: 28.2s	remaining: 3m 35s
# 550:	learn: 2383222.4017596	total: 28.3s	remaining: 3m 35s
# 551:	learn: 2383106.4434071	total: 28.3s	remaining: 3m 35s
# 552:	learn: 2382587.4855884	total: 28.4s	remaining: 3m 35s
# 553:	learn: 2382267.3949404	total: 28.4s	remaining: 3m 35s
# 554:	learn: 2382046.6074034	total: 28.5s	remaining: 3m 35s
# 555:	learn: 2381493.6594710	total: 28.5s	remaining: 3m 35s
# 556:	learn: 2381350.1513700	total: 28.6s	remaining: 3m 35s
# 557:	learn: 2381172.7617097	total: 28.6s	remaining: 3m 35s
# 558:	learn: 2380216.3890907	total: 28.6s	remaining: 3m 35s
# 559:	learn: 2379699.6433911	total: 28.7s	remaining: 3m 34s
# 560:	learn: 2379442.0642520	total: 28.8s	remaining: 3m 34s
# 561:	learn: 2378695.9466331	total: 28.8s	remaining: 3m 34s
# 562:	learn: 2378135.1868995	total: 28.9s	remaining: 3m 34s
# 563:	learn: 2377686.7292132	total: 28.9s	remaining: 3m 34s
# 564:	learn: 2377117.0668907	total: 28.9s	remaining: 3m 34s
# 565:	learn: 2376721.5921244	total: 29s	remaining: 3m 34s
# 566:	learn: 2376379.8211503	total: 29.1s	remaining: 3m 34s
# 567:	learn: 2375863.6781209	total: 29.1s	remaining: 3m 34s
# 568:	learn: 2374922.1137712	total: 29.1s	remaining: 3m 34s
# 569:	learn: 2374464.9340580	total: 29.2s	remaining: 3m 34s
# 570:	learn: 2374401.5886609	total: 29.2s	remaining: 3m 34s
# 571:	learn: 2374028.7417065	total: 29.3s	remaining: 3m 34s
# 572:	learn: 2373861.0795431	total: 29.3s	remaining: 3m 34s
# 573:	learn: 2373792.2331498	total: 29.4s	remaining: 3m 34s
# 574:	learn: 2373405.4493944	total: 29.4s	remaining: 3m 34s
# 575:	learn: 2373031.8872876	total: 29.5s	remaining: 3m 33s
# 576:	learn: 2372905.7777784	total: 29.5s	remaining: 3m 33s
# 577:	learn: 2372141.1222676	total: 29.6s	remaining: 3m 33s
# 578:	learn: 2371914.8185540	total: 29.6s	remaining: 3m 33s
# 579:	learn: 2371857.9700394	total: 29.7s	remaining: 3m 33s
# 580:	learn: 2371451.5662713	total: 29.7s	remaining: 3m 33s
# 581:	learn: 2371382.1850915	total: 29.8s	remaining: 3m 33s
# 582:	learn: 2370819.7502972	total: 29.8s	remaining: 3m 33s
# 583:	learn: 2370370.4619202	total: 29.9s	remaining: 3m 33s
# 584:	learn: 2369636.0423046	total: 29.9s	remaining: 3m 33s
# 585:	learn: 2369598.2400895	total: 30s	remaining: 3m 33s
# 586:	learn: 2368750.3633975	total: 30s	remaining: 3m 33s
# 587:	learn: 2368065.4291564	total: 30.1s	remaining: 3m 33s
# 588:	learn: 2367084.7807429	total: 30.1s	remaining: 3m 32s
# 589:	learn: 2367051.5174112	total: 30.2s	remaining: 3m 32s
# 590:	learn: 2366455.2949317	total: 30.2s	remaining: 3m 32s
# 591:	learn: 2366062.5555028	total: 30.3s	remaining: 3m 32s
# 592:	learn: 2365990.7916862	total: 30.3s	remaining: 3m 32s
# 593:	learn: 2365372.3219677	total: 30.4s	remaining: 3m 32s
# 594:	learn: 2364756.7129386	total: 30.4s	remaining: 3m 32s
# 595:	learn: 2363766.1682876	total: 30.5s	remaining: 3m 32s
# 596:	learn: 2362994.7472416	total: 30.5s	remaining: 3m 32s
# 597:	learn: 2362580.4435492	total: 30.6s	remaining: 3m 32s
# 598:	learn: 2362313.0175638	total: 30.6s	remaining: 3m 32s
# 599:	learn: 2362184.9323492	total: 30.6s	remaining: 3m 32s
# 600:	learn: 2361839.9298700	total: 30.7s	remaining: 3m 32s
# 601:	learn: 2361704.8186281	total: 30.7s	remaining: 3m 32s
# 602:	learn: 2361065.4474568	total: 30.8s	remaining: 3m 31s
# 603:	learn: 2360303.0976934	total: 30.8s	remaining: 3m 31s
# 604:	learn: 2359889.2487838	total: 30.9s	remaining: 3m 31s
# 605:	learn: 2359823.4150501	total: 30.9s	remaining: 3m 31s
# 606:	learn: 2359127.5041362	total: 31s	remaining: 3m 31s
# 607:	learn: 2358955.2159425	total: 31s	remaining: 3m 31s
# 608:	learn: 2358438.5616200	total: 31.1s	remaining: 3m 31s
# 609:	learn: 2358109.1140531	total: 31.1s	remaining: 3m 31s
# 610:	learn: 2357391.7072212	total: 31.2s	remaining: 3m 31s
# 611:	learn: 2356967.2187724	total: 31.2s	remaining: 3m 31s
# 612:	learn: 2356910.4074527	total: 31.3s	remaining: 3m 31s
# 613:	learn: 2356555.0040845	total: 31.3s	remaining: 3m 31s
# 614:	learn: 2356182.0461606	total: 31.4s	remaining: 3m 31s
# 615:	learn: 2356130.7473588	total: 31.5s	remaining: 3m 31s
# 616:	learn: 2355574.6369845	total: 31.5s	remaining: 3m 31s
# 617:	learn: 2354979.0503493	total: 31.6s	remaining: 3m 31s
# 618:	learn: 2354284.0479225	total: 31.6s	remaining: 3m 31s
# 619:	learn: 2353527.8176432	total: 31.7s	remaining: 3m 31s
# 620:	learn: 2353431.0762987	total: 31.7s	remaining: 3m 31s
# 621:	learn: 2353023.2778858	total: 31.8s	remaining: 3m 31s
# 622:	learn: 2352981.4872854	total: 31.8s	remaining: 3m 31s
# 623:	learn: 2352845.2786315	total: 31.9s	remaining: 3m 31s
# 624:	learn: 2352620.0716335	total: 31.9s	remaining: 3m 30s
# 625:	learn: 2352177.0600436	total: 32s	remaining: 3m 30s
# 626:	learn: 2351588.0048800	total: 32s	remaining: 3m 30s
# 627:	learn: 2351044.3894914	total: 32.1s	remaining: 3m 30s
# 628:	learn: 2350512.4958761	total: 32.2s	remaining: 3m 30s
# 629:	learn: 2350147.7605309	total: 32.2s	remaining: 3m 30s
# 630:	learn: 2349830.0700239	total: 32.3s	remaining: 3m 30s
# 631:	learn: 2349328.9118224	total: 32.3s	remaining: 3m 30s
# 632:	learn: 2349259.9516784	total: 32.4s	remaining: 3m 30s
# 633:	learn: 2349197.3980232	total: 32.4s	remaining: 3m 30s
# 634:	learn: 2348787.6494445	total: 32.7s	remaining: 3m 32s
# 635:	learn: 2348082.3959258	total: 32.7s	remaining: 3m 32s
# 636:	learn: 2348011.0637302	total: 32.8s	remaining: 3m 32s
# 637:	learn: 2347296.4042655	total: 32.8s	remaining: 3m 31s
# 638:	learn: 2346811.3355711	total: 32.9s	remaining: 3m 31s
# 639:	learn: 2346695.2178249	total: 33s	remaining: 3m 31s
# 640:	learn: 2346064.8731325	total: 33s	remaining: 3m 31s
# 641:	learn: 2345701.2322368	total: 33.1s	remaining: 3m 31s
# 642:	learn: 2345440.5538698	total: 33.1s	remaining: 3m 31s
# 643:	learn: 2345006.8509417	total: 33.2s	remaining: 3m 31s
# 644:	learn: 2344920.8542170	total: 33.2s	remaining: 3m 31s
# 645:	learn: 2344315.0519507	total: 33.3s	remaining: 3m 31s
# 646:	learn: 2343776.0545139	total: 33.4s	remaining: 3m 31s
# 647:	learn: 2343324.7398192	total: 33.4s	remaining: 3m 31s
# 648:	learn: 2342485.1059383	total: 33.5s	remaining: 3m 31s
# 649:	learn: 2342209.0161264	total: 33.5s	remaining: 3m 31s
# 650:	learn: 2341615.9669681	total: 33.6s	remaining: 3m 31s
# 651:	learn: 2341573.0023894	total: 33.6s	remaining: 3m 31s
# 652:	learn: 2341110.6676767	total: 33.7s	remaining: 3m 31s
# 653:	learn: 2340276.0760535	total: 33.7s	remaining: 3m 31s
# 654:	learn: 2340157.9486404	total: 33.8s	remaining: 3m 31s
# 655:	learn: 2339530.9757077	total: 33.9s	remaining: 3m 31s
# 656:	learn: 2338938.2587456	total: 33.9s	remaining: 3m 31s
# 657:	learn: 2338901.1216541	total: 34s	remaining: 3m 31s
# 658:	learn: 2338580.2170652	total: 34.1s	remaining: 3m 31s
# 659:	learn: 2337892.5144155	total: 34.1s	remaining: 3m 31s
# 660:	learn: 2337460.2857275	total: 34.2s	remaining: 3m 31s
# 661:	learn: 2337401.8960154	total: 34.3s	remaining: 3m 31s
# 662:	learn: 2337199.7115678	total: 34.3s	remaining: 3m 31s
# 663:	learn: 2336915.3293632	total: 34.4s	remaining: 3m 31s
# 664:	learn: 2336628.1372956	total: 34.4s	remaining: 3m 31s
# 665:	learn: 2336552.1531119	total: 34.5s	remaining: 3m 31s
# 666:	learn: 2336516.5564689	total: 34.6s	remaining: 3m 31s
# 667:	learn: 2336456.3694875	total: 34.6s	remaining: 3m 31s
# 668:	learn: 2335591.3334078	total: 34.7s	remaining: 3m 31s
# 669:	learn: 2335447.0490860	total: 34.8s	remaining: 3m 31s
# 670:	learn: 2334986.0865082	total: 34.8s	remaining: 3m 32s
# 671:	learn: 2334934.2076228	total: 34.9s	remaining: 3m 32s
# 672:	learn: 2334615.1449856	total: 35s	remaining: 3m 32s
# 673:	learn: 2334156.7483318	total: 35s	remaining: 3m 32s
# 674:	learn: 2333732.6943800	total: 35.1s	remaining: 3m 32s
# 675:	learn: 2333342.9565169	total: 35.1s	remaining: 3m 32s
# 676:	learn: 2332887.3881981	total: 35.2s	remaining: 3m 32s
# 677:	learn: 2332507.3444620	total: 35.3s	remaining: 3m 32s
# 678:	learn: 2332049.6358920	total: 35.3s	remaining: 3m 32s
# 679:	learn: 2331717.5238661	total: 35.4s	remaining: 3m 32s
# 680:	learn: 2331683.4336607	total: 35.5s	remaining: 3m 32s
# 681:	learn: 2331618.0150466	total: 35.5s	remaining: 3m 32s
# 682:	learn: 2331114.9691278	total: 35.6s	remaining: 3m 32s
# 683:	learn: 2330673.9575084	total: 35.6s	remaining: 3m 32s
# 684:	learn: 2330182.3509980	total: 35.7s	remaining: 3m 32s
# 685:	learn: 2329484.7106190	total: 35.8s	remaining: 3m 32s
# 686:	learn: 2329424.1639858	total: 35.9s	remaining: 3m 32s
# 687:	learn: 2329057.9892998	total: 35.9s	remaining: 3m 32s
# 688:	learn: 2328620.8420938	total: 36s	remaining: 3m 32s
# 689:	learn: 2327724.7069579	total: 36s	remaining: 3m 32s
# 690:	learn: 2327422.3087862	total: 36.1s	remaining: 3m 32s
# 691:	learn: 2326793.2128792	total: 36.2s	remaining: 3m 32s
# 692:	learn: 2326648.7903608	total: 36.2s	remaining: 3m 32s
# 693:	learn: 2325687.5235167	total: 36.3s	remaining: 3m 32s
# 694:	learn: 2325268.1715199	total: 36.3s	remaining: 3m 32s
# 695:	learn: 2324955.7558791	total: 36.4s	remaining: 3m 32s
# 696:	learn: 2324823.9577287	total: 36.5s	remaining: 3m 32s
# 697:	learn: 2324237.8633563	total: 36.5s	remaining: 3m 32s
# 698:	learn: 2324087.0375960	total: 36.6s	remaining: 3m 32s
# 699:	learn: 2323426.6916444	total: 36.6s	remaining: 3m 32s
# 700:	learn: 2323261.3505527	total: 36.7s	remaining: 3m 32s
# 701:	learn: 2322628.7709057	total: 36.8s	remaining: 3m 32s
# 702:	learn: 2322570.1607652	total: 36.8s	remaining: 3m 32s
# 703:	learn: 2322532.9850200	total: 36.9s	remaining: 3m 32s
# 704:	learn: 2322109.8133268	total: 37s	remaining: 3m 32s
# 705:	learn: 2321827.7874876	total: 37s	remaining: 3m 32s
# 706:	learn: 2321208.3081563	total: 37.1s	remaining: 3m 32s
# 707:	learn: 2321180.0766249	total: 37.1s	remaining: 3m 32s
# 708:	learn: 2320898.5975865	total: 37.2s	remaining: 3m 32s
# 709:	learn: 2320800.4032304	total: 37.3s	remaining: 3m 32s
# 710:	learn: 2320192.9448985	total: 37.3s	remaining: 3m 32s
# 711:	learn: 2319628.0021201	total: 37.4s	remaining: 3m 32s
# 712:	learn: 2319091.3173725	total: 37.5s	remaining: 3m 32s
# 713:	learn: 2318563.6497334	total: 37.5s	remaining: 3m 32s
# 714:	learn: 2318178.2346459	total: 37.6s	remaining: 3m 32s
# 715:	learn: 2317535.2527797	total: 37.7s	remaining: 3m 32s
# 716:	learn: 2316874.9763736	total: 37.7s	remaining: 3m 32s
# 717:	learn: 2316414.4853572	total: 37.8s	remaining: 3m 32s
# 718:	learn: 2316112.9704897	total: 37.9s	remaining: 3m 32s
# 719:	learn: 2315277.9888875	total: 37.9s	remaining: 3m 32s
# 720:	learn: 2315010.0644375	total: 38s	remaining: 3m 32s
# 721:	learn: 2314327.2666913	total: 38.1s	remaining: 3m 32s
# 722:	learn: 2313721.4036770	total: 38.1s	remaining: 3m 32s
# 723:	learn: 2313664.7534625	total: 38.2s	remaining: 3m 32s
# 724:	learn: 2312986.1201596	total: 38.2s	remaining: 3m 32s
# 725:	learn: 2312386.3101210	total: 38.3s	remaining: 3m 32s
# 726:	learn: 2312329.2796621	total: 38.4s	remaining: 3m 32s
# 727:	learn: 2311686.5486821	total: 38.4s	remaining: 3m 32s
# 728:	learn: 2311296.6445772	total: 38.5s	remaining: 3m 32s
# 729:	learn: 2311142.5385989	total: 38.5s	remaining: 3m 32s
# 730:	learn: 2310906.0319125	total: 38.6s	remaining: 3m 32s
# 731:	learn: 2310402.0438467	total: 38.7s	remaining: 3m 32s
# 732:	learn: 2309575.8161408	total: 38.7s	remaining: 3m 32s
# 733:	learn: 2308760.7243189	total: 38.8s	remaining: 3m 32s
# 734:	learn: 2308708.3647716	total: 38.9s	remaining: 3m 32s
# 735:	learn: 2307985.4691153	total: 39s	remaining: 3m 32s
# 736:	learn: 2307426.1408138	total: 39s	remaining: 3m 32s
# 737:	learn: 2307005.9059388	total: 39.1s	remaining: 3m 32s
# 738:	learn: 2306641.7488622	total: 39.2s	remaining: 3m 32s
# 739:	learn: 2306073.9616259	total: 39.2s	remaining: 3m 32s
# 740:	learn: 2305660.6699576	total: 39.3s	remaining: 3m 32s
# 741:	learn: 2305014.6012250	total: 39.4s	remaining: 3m 32s
# 742:	learn: 2304959.7025334	total: 39.4s	remaining: 3m 32s
# 743:	learn: 2304534.8433951	total: 39.5s	remaining: 3m 32s
# 744:	learn: 2303717.2514379	total: 39.5s	remaining: 3m 32s
# 745:	learn: 2302848.4859927	total: 39.6s	remaining: 3m 32s
# 746:	learn: 2302567.6472958	total: 39.7s	remaining: 3m 32s
# 747:	learn: 2302071.6583541	total: 39.7s	remaining: 3m 32s
# 748:	learn: 2301454.0048770	total: 39.8s	remaining: 3m 32s
# 749:	learn: 2301403.3826613	total: 39.9s	remaining: 3m 32s
# 750:	learn: 2300979.2116592	total: 39.9s	remaining: 3m 32s
# 751:	learn: 2300950.9897244	total: 40s	remaining: 3m 32s
# 752:	learn: 2300393.5005702	total: 40.1s	remaining: 3m 32s
# 753:	learn: 2300096.1291442	total: 40.1s	remaining: 3m 32s
# 754:	learn: 2299336.8524746	total: 40.2s	remaining: 3m 32s
# 755:	learn: 2299284.8750214	total: 40.3s	remaining: 3m 33s
# 756:	learn: 2299191.2441163	total: 40.3s	remaining: 3m 32s
# 757:	learn: 2298905.6550230	total: 40.4s	remaining: 3m 32s
# 758:	learn: 2298306.6256504	total: 40.5s	remaining: 3m 33s
# 759:	learn: 2297671.6938964	total: 40.6s	remaining: 3m 33s
# 760:	learn: 2297059.1792214	total: 40.6s	remaining: 3m 33s
# 761:	learn: 2296535.3554048	total: 40.7s	remaining: 3m 33s
# 762:	learn: 2296102.7472729	total: 40.8s	remaining: 3m 33s
# 763:	learn: 2295971.8596865	total: 40.8s	remaining: 3m 33s
# 764:	learn: 2295369.5743930	total: 40.9s	remaining: 3m 33s
# 765:	learn: 2295191.1625579	total: 40.9s	remaining: 3m 33s
# 766:	learn: 2294593.9457741	total: 41s	remaining: 3m 33s
# 767:	learn: 2294187.8761169	total: 41.1s	remaining: 3m 33s
# 768:	learn: 2293663.1553733	total: 41.1s	remaining: 3m 33s
# 769:	learn: 2293276.9691500	total: 41.2s	remaining: 3m 33s
# 770:	learn: 2293120.6601201	total: 41.3s	remaining: 3m 33s
# 771:	learn: 2292715.1847028	total: 41.3s	remaining: 3m 33s
# 772:	learn: 2292278.5601364	total: 41.4s	remaining: 3m 33s
# 773:	learn: 2291660.7070003	total: 41.5s	remaining: 3m 33s
# 774:	learn: 2290949.2259445	total: 41.5s	remaining: 3m 33s
# 775:	learn: 2290383.9157478	total: 41.6s	remaining: 3m 33s
# 776:	learn: 2289832.1359768	total: 41.6s	remaining: 3m 33s
# 777:	learn: 2289442.7213212	total: 41.7s	remaining: 3m 33s
# 778:	learn: 2288673.5143201	total: 41.8s	remaining: 3m 33s
# 779:	learn: 2288092.0057204	total: 41.9s	remaining: 3m 33s
# 780:	learn: 2287531.4080478	total: 41.9s	remaining: 3m 33s
# 781:	learn: 2287051.9338144	total: 42s	remaining: 3m 33s
# 782:	learn: 2286482.1310308	total: 42s	remaining: 3m 33s
# 783:	learn: 2286037.3724628	total: 42.1s	remaining: 3m 33s
# 784:	learn: 2285289.2470844	total: 42.2s	remaining: 3m 33s
# 785:	learn: 2284846.7199108	total: 42.2s	remaining: 3m 33s
# 786:	learn: 2284396.9895300	total: 42.3s	remaining: 3m 33s
# 787:	learn: 2283660.4862417	total: 42.4s	remaining: 3m 33s
# 788:	learn: 2283393.4222395	total: 42.4s	remaining: 3m 33s
# 789:	learn: 2282899.4971323	total: 42.5s	remaining: 3m 33s
# 790:	learn: 2282862.1846901	total: 42.6s	remaining: 3m 33s
# 791:	learn: 2282289.9301125	total: 42.6s	remaining: 3m 33s
# 792:	learn: 2281571.7667069	total: 42.7s	remaining: 3m 33s
# 793:	learn: 2281189.4113089	total: 42.8s	remaining: 3m 33s
# 794:	learn: 2280613.1010170	total: 42.8s	remaining: 3m 33s
# 795:	learn: 2280288.5400967	total: 42.9s	remaining: 3m 33s
# 796:	learn: 2279483.2725304	total: 43s	remaining: 3m 33s
# 797:	learn: 2278972.4942965	total: 43s	remaining: 3m 33s
# 798:	learn: 2278402.1833464	total: 43.1s	remaining: 3m 33s
# 799:	learn: 2278016.5931448	total: 43.1s	remaining: 3m 33s
# 800:	learn: 2277492.2806426	total: 43.2s	remaining: 3m 33s
# 801:	learn: 2276936.5460601	total: 43.3s	remaining: 3m 33s
# 802:	learn: 2276462.6131828	total: 43.3s	remaining: 3m 33s
# 803:	learn: 2276238.4324225	total: 43.4s	remaining: 3m 33s
# 804:	learn: 2275666.7484855	total: 43.5s	remaining: 3m 33s
# 805:	learn: 2275112.1941251	total: 43.5s	remaining: 3m 33s
# 806:	learn: 2274561.1185045	total: 43.6s	remaining: 3m 33s
# 807:	learn: 2274065.5315886	total: 43.7s	remaining: 3m 33s
# 808:	learn: 2273595.1761317	total: 43.7s	remaining: 3m 33s
# 809:	learn: 2273549.1167527	total: 43.8s	remaining: 3m 33s
# 810:	learn: 2272900.5744251	total: 43.8s	remaining: 3m 33s
# 811:	learn: 2272265.3267031	total: 43.9s	remaining: 3m 33s
# 812:	learn: 2271707.6802767	total: 44s	remaining: 3m 33s
# 813:	learn: 2271238.1807056	total: 44s	remaining: 3m 33s
# 814:	learn: 2270827.7175647	total: 44.1s	remaining: 3m 33s
# 815:	learn: 2270102.0722769	total: 44.1s	remaining: 3m 33s
# 816:	learn: 2269848.4593793	total: 44.2s	remaining: 3m 33s
# 817:	learn: 2269683.9271303	total: 44.3s	remaining: 3m 33s
# 818:	learn: 2269514.7326532	total: 44.3s	remaining: 3m 33s
# 819:	learn: 2269192.5600868	total: 44.4s	remaining: 3m 33s
# ...
# 4488:	learn: 1673298.7772668	total: 4m 43s	remaining: 16.8s
# 4489:	learn: 1673178.8073078	total: 4m 43s	remaining: 16.7s
# 4490:	learn: 1673102.3308750	total: 4m 43s	remaining: 16.7s
# 4491:	learn: 1673030.7474107	total: 4m 43s	remaining: 16.6s
# 4492:	learn: 1672958.0051213	total: 4m 43s	remaining: 16.5s
# 4493:	learn: 1672830.6371259	total: 4m 43s	remaining: 16.5s
# 4494:	learn: 1672823.7084479	total: 4m 43s	remaining: 16.4s
# 4495:	learn: 1672747.6681469	total: 4m 43s	remaining: 16.3s
# 4496:	learn: 1672621.8254642	total: 4m 43s	remaining: 16.3s
# 4497:	learn: 1672612.4539815	total: 4m 43s	remaining: 16.2s
# 4498:	learn: 1672555.6309341	total: 4m 43s	remaining: 16.1s
# 4499:	learn: 1672450.4565201	total: 4m 43s	remaining: 16.1s
# 4500:	learn: 1672284.0129292	total: 4m 43s	remaining: 16s
# 4501:	learn: 1672147.5981045	total: 4m 43s	remaining: 16s
# 4502:	learn: 1672018.8511199	total: 4m 44s	remaining: 15.9s
# 4503:	learn: 1671907.0862927	total: 4m 44s	remaining: 15.8s
# 4504:	learn: 1671867.6543311	total: 4m 44s	remaining: 15.8s
# 4505:	learn: 1671857.8163168	total: 4m 44s	remaining: 15.7s
# 4506:	learn: 1671811.8049294	total: 4m 44s	remaining: 15.6s
# 4507:	learn: 1671752.3480765	total: 4m 44s	remaining: 15.6s
# 4508:	learn: 1671654.0097436	total: 4m 44s	remaining: 15.5s
# 4509:	learn: 1671567.6807168	total: 4m 44s	remaining: 15.5s
# 4510:	learn: 1671503.9800609	total: 4m 44s	remaining: 15.4s
# 4511:	learn: 1671442.8611973	total: 4m 44s	remaining: 15.3s
# 4512:	learn: 1671399.6308968	total: 4m 44s	remaining: 15.3s
# 4513:	learn: 1671342.9717002	total: 4m 44s	remaining: 15.2s
# 4514:	learn: 1671330.2981625	total: 4m 44s	remaining: 15.1s
# 4515:	learn: 1671228.5799596	total: 4m 44s	remaining: 15.1s
# 4516:	learn: 1671087.2047850	total: 4m 44s	remaining: 15s
# 4517:	learn: 1671063.2477675	total: 4m 44s	remaining: 14.9s
# 4518:	learn: 1670940.4362082	total: 4m 45s	remaining: 14.9s
# 4519:	learn: 1670856.1564363	total: 4m 45s	remaining: 14.8s
# 4520:	learn: 1670793.2192933	total: 4m 45s	remaining: 14.8s
# 4521:	learn: 1670702.7039109	total: 4m 45s	remaining: 14.7s
# 4522:	learn: 1670576.7507823	total: 4m 45s	remaining: 14.6s
# 4523:	learn: 1670496.2186428	total: 4m 45s	remaining: 14.6s
# 4524:	learn: 1670362.0588776	total: 4m 45s	remaining: 14.5s
# 4525:	learn: 1670319.8539944	total: 4m 45s	remaining: 14.4s
# 4526:	learn: 1670221.0628692	total: 4m 45s	remaining: 14.4s
# 4527:	learn: 1670166.4724976	total: 4m 45s	remaining: 14.3s
# 4528:	learn: 1670121.0722218	total: 4m 45s	remaining: 14.3s
# 4529:	learn: 1669988.7496428	total: 4m 45s	remaining: 14.2s
# 4530:	learn: 1669930.0896378	total: 4m 45s	remaining: 14.1s
# 4531:	learn: 1669906.2130996	total: 4m 45s	remaining: 14.1s
# 4532:	learn: 1669901.6585522	total: 4m 45s	remaining: 14s
# 4533:	learn: 1669769.9357945	total: 4m 45s	remaining: 13.9s
# 4534:	learn: 1669707.3769011	total: 4m 45s	remaining: 13.9s
# 4535:	learn: 1669516.4435394	total: 4m 46s	remaining: 13.8s
# 4536:	learn: 1669501.6723868	total: 4m 46s	remaining: 13.7s
# 4537:	learn: 1669417.7590466	total: 4m 46s	remaining: 13.7s
# 4538:	learn: 1669305.9597128	total: 4m 46s	remaining: 13.6s
# 4539:	learn: 1669242.0337725	total: 4m 46s	remaining: 13.6s
# 4540:	learn: 1669174.6710354	total: 4m 46s	remaining: 13.5s
# 4541:	learn: 1669119.4515558	total: 4m 46s	remaining: 13.4s
# 4542:	learn: 1669085.8913177	total: 4m 46s	remaining: 13.4s
# 4543:	learn: 1668985.3688184	total: 4m 46s	remaining: 13.3s
# 4544:	learn: 1668848.3216670	total: 4m 46s	remaining: 13.2s
# 4545:	learn: 1668822.3331636	total: 4m 46s	remaining: 13.2s
# 4546:	learn: 1668737.2373692	total: 4m 46s	remaining: 13.1s
# 4547:	learn: 1668726.5253157	total: 4m 46s	remaining: 13.1s
# 4548:	learn: 1668652.3791734	total: 4m 46s	remaining: 13s
# 4549:	learn: 1668628.5602823	total: 4m 46s	remaining: 12.9s
# 4550:	learn: 1668579.8471700	total: 4m 46s	remaining: 12.9s
# 4551:	learn: 1668524.1598468	total: 4m 47s	remaining: 12.8s
# 4552:	learn: 1668416.4493975	total: 4m 47s	remaining: 12.7s
# 4553:	learn: 1668379.7648413	total: 4m 47s	remaining: 12.7s
# 4554:	learn: 1668308.4102685	total: 4m 47s	remaining: 12.6s
# 4555:	learn: 1668279.5985255	total: 4m 47s	remaining: 12.5s
# 4556:	learn: 1668222.4951870	total: 4m 47s	remaining: 12.5s
# 4557:	learn: 1668170.2099642	total: 4m 47s	remaining: 12.4s
# 4558:	learn: 1668115.4419904	total: 4m 47s	remaining: 12.4s
# 4559:	learn: 1668023.5959322	total: 4m 47s	remaining: 12.3s
# 4560:	learn: 1667913.4645096	total: 4m 47s	remaining: 12.2s
# 4561:	learn: 1667884.0229849	total: 4m 47s	remaining: 12.2s
# 4562:	learn: 1667785.6600081	total: 4m 47s	remaining: 12.1s
# 4563:	learn: 1667744.2317417	total: 4m 47s	remaining: 12s
# 4564:	learn: 1667649.3955212	total: 4m 47s	remaining: 12s
# 4565:	learn: 1667499.2373726	total: 4m 47s	remaining: 11.9s
# 4566:	learn: 1667414.6515963	total: 4m 47s	remaining: 11.9s
# 4567:	learn: 1667313.9366255	total: 4m 47s	remaining: 11.8s
# 4568:	learn: 1667299.1086419	total: 4m 48s	remaining: 11.7s
# 4569:	learn: 1667278.9228308	total: 4m 48s	remaining: 11.7s
# 4570:	learn: 1667080.2481073	total: 4m 48s	remaining: 11.6s
# 4571:	learn: 1667053.3182539	total: 4m 48s	remaining: 11.5s
# 4572:	learn: 1667045.7321201	total: 4m 48s	remaining: 11.5s
# 4573:	learn: 1666974.9199278	total: 4m 48s	remaining: 11.4s
# 4574:	learn: 1666929.3812971	total: 4m 48s	remaining: 11.3s
# 4575:	learn: 1666906.4078774	total: 4m 48s	remaining: 11.3s
# 4576:	learn: 1666904.6835068	total: 4m 48s	remaining: 11.2s
# 4577:	learn: 1666796.7157500	total: 4m 48s	remaining: 11.2s
# 4578:	learn: 1666737.2254496	total: 4m 48s	remaining: 11.1s
# 4579:	learn: 1666635.1702519	total: 4m 48s	remaining: 11s
# 4580:	learn: 1666557.3838698	total: 4m 48s	remaining: 11s
# 4581:	learn: 1666479.9641526	total: 4m 48s	remaining: 10.9s
# 4582:	learn: 1666436.6227127	total: 4m 48s	remaining: 10.8s
# 4583:	learn: 1666419.4226909	total: 4m 48s	remaining: 10.8s
# 4584:	learn: 1666295.4896508	total: 4m 48s	remaining: 10.7s
# 4585:	learn: 1666157.4645762	total: 4m 48s	remaining: 10.6s
# 4586:	learn: 1666150.0794526	total: 4m 48s	remaining: 10.6s
# 4587:	learn: 1666133.4634810	total: 4m 49s	remaining: 10.5s
# 4588:	learn: 1666110.9095262	total: 4m 49s	remaining: 10.5s
# 4589:	learn: 1666024.7969169	total: 4m 49s	remaining: 10.4s
# 4590:	learn: 1666002.6447969	total: 4m 49s	remaining: 10.3s
# 4591:	learn: 1665854.5127175	total: 4m 49s	remaining: 10.3s
# 4592:	learn: 1665783.6916891	total: 4m 49s	remaining: 10.2s
# 4593:	learn: 1665708.9424674	total: 4m 49s	remaining: 10.1s
# 4594:	learn: 1665616.2191992	total: 4m 49s	remaining: 10.1s
# 4595:	learn: 1665548.1238182	total: 4m 49s	remaining: 10s
# 4596:	learn: 1665542.1695258	total: 4m 50s	remaining: 9.97s
# 4597:	learn: 1665463.5560586	total: 4m 50s	remaining: 9.91s
# 4598:	learn: 1665349.0907246	total: 4m 50s	remaining: 9.85s
# 4599:	learn: 1665295.4536829	total: 4m 50s	remaining: 9.78s
# 4600:	learn: 1665293.7903904	total: 4m 50s	remaining: 9.72s
# 4601:	learn: 1665252.6420375	total: 4m 50s	remaining: 9.66s
# 4602:	learn: 1665162.2996246	total: 4m 50s	remaining: 9.59s
# 4603:	learn: 1665133.3518447	total: 4m 50s	remaining: 9.53s
# 4604:	learn: 1664985.8241559	total: 4m 50s	remaining: 9.47s
# 4605:	learn: 1664945.1194377	total: 4m 50s	remaining: 9.4s
# 4606:	learn: 1664889.3311550	total: 4m 50s	remaining: 9.34s
# 4607:	learn: 1664838.1114687	total: 4m 50s	remaining: 9.28s
# 4608:	learn: 1664704.1281192	total: 4m 50s	remaining: 9.21s
# 4609:	learn: 1664631.0009429	total: 4m 50s	remaining: 9.15s
# 4610:	learn: 1664537.4607987	total: 4m 51s	remaining: 9.09s
# 4611:	learn: 1664416.8402811	total: 4m 51s	remaining: 9.03s
# 4612:	learn: 1664272.9548236	total: 4m 51s	remaining: 8.96s
# 4613:	learn: 1664101.9240210	total: 4m 51s	remaining: 8.9s
# 4614:	learn: 1663957.2341830	total: 4m 51s	remaining: 8.84s
# 4615:	learn: 1663876.3796960	total: 4m 51s	remaining: 8.77s
# 4616:	learn: 1663816.3527456	total: 4m 51s	remaining: 8.71s
# 4617:	learn: 1663736.5304811	total: 4m 51s	remaining: 8.65s
# 4618:	learn: 1663708.5349551	total: 4m 51s	remaining: 8.58s
# 4619:	learn: 1663557.3063626	total: 4m 51s	remaining: 8.52s
# 4620:	learn: 1663491.8707542	total: 4m 51s	remaining: 8.46s
# 4621:	learn: 1663481.2988249	total: 4m 51s	remaining: 8.39s
# 4622:	learn: 1663422.1948292	total: 4m 51s	remaining: 8.33s
# 4623:	learn: 1663380.0656183	total: 4m 51s	remaining: 8.27s
# 4624:	learn: 1663271.5087705	total: 4m 51s	remaining: 8.2s
# 4625:	learn: 1663144.7019455	total: 4m 51s	remaining: 8.14s
# 4626:	learn: 1663074.2170280	total: 4m 52s	remaining: 8.08s
# 4627:	learn: 1663072.5919606	total: 4m 52s	remaining: 8.02s
# 4628:	learn: 1662956.4713780	total: 4m 52s	remaining: 7.95s
# 4629:	learn: 1662792.6986794	total: 4m 52s	remaining: 7.89s
# 4630:	learn: 1662745.3586397	total: 4m 52s	remaining: 7.83s
# 4631:	learn: 1662682.2943585	total: 4m 52s	remaining: 7.76s
# 4632:	learn: 1662619.1856208	total: 4m 52s	remaining: 7.7s
# 4633:	learn: 1662555.6819874	total: 4m 52s	remaining: 7.64s
# 4634:	learn: 1662471.7478729	total: 4m 52s	remaining: 7.57s
# 4635:	learn: 1662385.0636201	total: 4m 52s	remaining: 7.51s
# 4636:	learn: 1662347.8687177	total: 4m 52s	remaining: 7.45s
# 4637:	learn: 1662313.0624572	total: 4m 52s	remaining: 7.38s
# 4638:	learn: 1662293.3210788	total: 4m 52s	remaining: 7.32s
# 4639:	learn: 1662235.9197083	total: 4m 52s	remaining: 7.26s
# 4640:	learn: 1662188.1406815	total: 4m 52s	remaining: 7.2s
# 4641:	learn: 1662031.1789177	total: 4m 53s	remaining: 7.13s
# 4642:	learn: 1661981.9159492	total: 4m 53s	remaining: 7.07s
# 4643:	learn: 1661931.3558820	total: 4m 53s	remaining: 7.01s
# 4644:	learn: 1661926.8211653	total: 4m 53s	remaining: 6.94s
# 4645:	learn: 1661758.5515990	total: 4m 53s	remaining: 6.88s
# 4646:	learn: 1661692.2845607	total: 4m 53s	remaining: 6.82s
# 4647:	learn: 1661628.2056045	total: 4m 53s	remaining: 6.75s
# 4648:	learn: 1661547.4355724	total: 4m 53s	remaining: 6.69s
# 4649:	learn: 1661508.5653413	total: 4m 53s	remaining: 6.63s
# 4650:	learn: 1661496.3559985	total: 4m 53s	remaining: 6.56s
# 4651:	learn: 1661460.9157253	total: 4m 53s	remaining: 6.5s
# 4652:	learn: 1661389.9832390	total: 4m 53s	remaining: 6.44s
# 4653:	learn: 1661323.7708704	total: 4m 53s	remaining: 6.37s
# 4654:	learn: 1661279.8772583	total: 4m 53s	remaining: 6.31s
# 4655:	learn: 1661278.2919031	total: 4m 53s	remaining: 6.25s
# 4656:	learn: 1661204.1301695	total: 4m 53s	remaining: 6.18s
# 4657:	learn: 1661098.5867779	total: 4m 53s	remaining: 6.12s
# 4658:	learn: 1660953.5839434	total: 4m 54s	remaining: 6.06s
# 4659:	learn: 1660865.8733262	total: 4m 54s	remaining: 6s
# 4660:	learn: 1660760.8450032	total: 4m 54s	remaining: 5.93s
# 4661:	learn: 1660644.7156014	total: 4m 54s	remaining: 5.87s
# 4662:	learn: 1660572.0213544	total: 4m 54s	remaining: 5.81s
# 4663:	learn: 1660523.1311609	total: 4m 54s	remaining: 5.74s
# 4664:	learn: 1660397.1328120	total: 4m 54s	remaining: 5.68s
# 4665:	learn: 1660355.8629230	total: 4m 54s	remaining: 5.62s
# 4666:	learn: 1660286.4527048	total: 4m 54s	remaining: 5.55s
# 4667:	learn: 1660278.8457831	total: 4m 54s	remaining: 5.49s
# 4668:	learn: 1660259.3751557	total: 4m 54s	remaining: 5.43s
# 4669:	learn: 1660138.2924231	total: 4m 54s	remaining: 5.36s
# 4670:	learn: 1660047.8546751	total: 4m 54s	remaining: 5.3s
# 4671:	learn: 1659890.1043350	total: 4m 54s	remaining: 5.24s
# 4672:	learn: 1659876.8690130	total: 4m 54s	remaining: 5.17s
# 4673:	learn: 1659816.3527532	total: 4m 54s	remaining: 5.11s
# 4674:	learn: 1659718.3908833	total: 4m 55s	remaining: 5.05s
# 4675:	learn: 1659716.8474131	total: 4m 55s	remaining: 4.99s
# 4676:	learn: 1659641.2531266	total: 4m 55s	remaining: 4.92s
# 4677:	learn: 1659601.4235209	total: 4m 55s	remaining: 4.86s
# 4678:	learn: 1659483.4354575	total: 4m 55s	remaining: 4.79s
# 4679:	learn: 1659401.7168706	total: 4m 55s	remaining: 4.73s
# 4680:	learn: 1659241.9547755	total: 4m 55s	remaining: 4.67s
# 4681:	learn: 1659179.2000984	total: 4m 55s	remaining: 4.61s
# 4682:	learn: 1659065.8291262	total: 4m 55s	remaining: 4.54s
# 4683:	learn: 1659024.7507692	total: 4m 55s	remaining: 4.48s
# 4684:	learn: 1658982.2352354	total: 4m 55s	remaining: 4.42s
# 4685:	learn: 1658980.7173576	total: 4m 55s	remaining: 4.35s
# 4686:	learn: 1658942.9859868	total: 4m 55s	remaining: 4.29s
# 4687:	learn: 1658877.6613698	total: 4m 55s	remaining: 4.23s
# 4688:	learn: 1658783.6019381	total: 4m 55s	remaining: 4.16s
# 4689:	learn: 1658679.2613963	total: 4m 55s	remaining: 4.1s
# 4690:	learn: 1658618.8231345	total: 4m 56s	remaining: 4.04s
# 4691:	learn: 1658546.6376260	total: 4m 56s	remaining: 3.98s
# 4692:	learn: 1658536.9571705	total: 4m 56s	remaining: 3.91s
# 4693:	learn: 1658527.4624481	total: 4m 56s	remaining: 3.85s
# 4694:	learn: 1658525.9707021	total: 4m 56s	remaining: 3.79s
# 4695:	learn: 1658480.5529455	total: 4m 56s	remaining: 3.72s
# 4696:	learn: 1658333.2929142	total: 4m 56s	remaining: 3.66s
# 4697:	learn: 1658237.2361330	total: 4m 56s	remaining: 3.6s
# 4698:	learn: 1658086.2205543	total: 4m 56s	remaining: 3.53s
# 4699:	learn: 1658046.4274219	total: 4m 56s	remaining: 3.47s
# 4700:	learn: 1658010.5772316	total: 4m 56s	remaining: 3.41s
# 4701:	learn: 1657929.3208404	total: 4m 56s	remaining: 3.34s
# 4702:	learn: 1657864.8356039	total: 4m 56s	remaining: 3.28s
# 4703:	learn: 1657840.5893959	total: 4m 56s	remaining: 3.22s
# 4704:	learn: 1657784.5689644	total: 4m 56s	remaining: 3.15s
# 4705:	learn: 1657720.5242834	total: 4m 57s	remaining: 3.09s
# 4706:	learn: 1657719.0525532	total: 4m 57s	remaining: 3.03s
# 4707:	learn: 1657587.5378533	total: 4m 57s	remaining: 2.97s
# 4708:	learn: 1657516.1205488	total: 4m 57s	remaining: 2.9s
# 4709:	learn: 1657440.8534405	total: 4m 57s	remaining: 2.84s
# 4710:	learn: 1657400.7227503	total: 4m 57s	remaining: 2.78s
# 4711:	learn: 1657336.7808568	total: 4m 57s	remaining: 2.71s
# 4712:	learn: 1657189.4274425	total: 4m 57s	remaining: 2.65s
# 4713:	learn: 1657066.4732574	total: 4m 57s	remaining: 2.59s
# 4714:	learn: 1657065.0146887	total: 4m 57s	remaining: 2.52s
# 4715:	learn: 1657025.5025348	total: 4m 57s	remaining: 2.46s
# 4716:	learn: 1656994.7591715	total: 4m 57s	remaining: 2.4s
# 4717:	learn: 1656930.6435456	total: 4m 57s	remaining: 2.34s
# 4718:	learn: 1656775.0748474	total: 4m 57s	remaining: 2.27s
# 4719:	learn: 1656699.2289403	total: 4m 58s	remaining: 2.21s
# 4720:	learn: 1656625.6293416	total: 4m 58s	remaining: 2.15s
# 4721:	learn: 1656548.0571992	total: 4m 58s	remaining: 2.08s
# 4722:	learn: 1656432.6869307	total: 4m 58s	remaining: 2.02s
# 4723:	learn: 1656317.2497397	total: 4m 58s	remaining: 1.96s
# 4724:	learn: 1656278.7069001	total: 4m 58s	remaining: 1.9s
# 4725:	learn: 1656277.1181315	total: 4m 58s	remaining: 1.83s
# 4726:	learn: 1656209.4146569	total: 4m 58s	remaining: 1.77s
# 4727:	learn: 1656207.7162498	total: 4m 58s	remaining: 1.71s
# 4728:	learn: 1656140.8007676	total: 4m 58s	remaining: 1.64s
# 4729:	learn: 1656028.2126235	total: 4m 58s	remaining: 1.58s
# 4730:	learn: 1656021.4499107	total: 4m 58s	remaining: 1.52s
# 4731:	learn: 1655932.2861980	total: 4m 58s	remaining: 1.45s
# 4732:	learn: 1655785.2839468	total: 4m 59s	remaining: 1.39s
# 4733:	learn: 1655774.8768069	total: 4m 59s	remaining: 1.33s
# 4734:	learn: 1655770.2263058	total: 4m 59s	remaining: 1.26s
# 4735:	learn: 1655754.6631619	total: 4m 59s	remaining: 1.2s
# 4736:	learn: 1655695.6167181	total: 4m 59s	remaining: 1.14s
# 4737:	learn: 1655676.4004124	total: 4m 59s	remaining: 1.07s
# 4738:	learn: 1655569.8691447	total: 4m 59s	remaining: 1.01s
# 4739:	learn: 1655417.7572031	total: 4m 59s	remaining: 948ms
# 4740:	learn: 1655364.7855829	total: 4m 59s	remaining: 885ms
# 4741:	learn: 1655189.2829476	total: 4m 59s	remaining: 822ms
# 4742:	learn: 1655185.3637676	total: 4m 59s	remaining: 758ms
# 4743:	learn: 1655106.4396592	total: 4m 59s	remaining: 695ms
# 4744:	learn: 1654967.3126831	total: 4m 59s	remaining: 632ms
# 4745:	learn: 1654837.5396488	total: 5m	remaining: 569ms
# 4746:	learn: 1654752.0586291	total: 5m	remaining: 506ms
# 4747:	learn: 1654623.6206300	total: 5m	remaining: 443ms
# 4748:	learn: 1654562.4046520	total: 5m	remaining: 379ms
# 4749:	learn: 1654560.8527894	total: 5m	remaining: 316ms
# 4750:	learn: 1654559.3208180	total: 5m	remaining: 253ms
# 4751:	learn: 1654481.4115011	total: 5m	remaining: 190ms
# 4752:	learn: 1654388.7749831	total: 5m	remaining: 126ms
# 4753:	learn: 1654283.1084132	total: 5m	remaining: 63.2ms
# 4754:	learn: 1654222.1149614	total: 5m	remaining: 0us
# 0.4145849709182293

# %%
pred_target = best_model.predict(test[columns])

# %%
# выгрузим результаты
predicted_result = pd.DataFrame({'id': id_test, 'price_doc': pred_target})
predicted_result.to_csv('kaggle_submission.csv', index=False)

# %% [markdown]
# # Часть 3. Создание дэшборда

# %%
# загружаем ранее выгруженные обработанные данные
df_data = pd.read_csv('processed_data.csv')

# %%
# загружаем модель
pkl_filename = "pickle_model.pkl" 
with open(pkl_filename, 'rb') as file:
    loaded_model = pickle.load(file)

# %%
# формируем датасет из наиболее часто встречаемых значений
most_freq_df = df_data.mode()[loaded_model.feature_names_]

# %%
'''from scipy.stats import skew, mode
most_freq_df = most_freq_df.groupby('sub_area').agg(mode)
col = most_freq_df.columns
for column in most_freq_df.columns:
    most_freq_df[column] = most_freq_df[column].str[0].str[0]
most_freq_df = most_freq_df.reset_index()
most_freq_df['year'] = 2022
most_freq_df = most_freq_df.reindex(columns=loaded_model.feature_names_)'''
# Out:
# "from scipy.stats import skew, mode\nmost_freq_df = most_freq_df.groupby('sub_area').agg(mode)\ncol = most_freq_df.columns\nfor column in most_freq_df.columns:\n    most_freq_df[column] = most_freq_df[column].str[0].str[0]\nmost_freq_df = most_freq_df.reset_index()\nmost_freq_df['year'] = 2022\nmost_freq_df = most_freq_df.reindex(columns=loaded_model.feature_names_)"

# %%
# загружаем геоданные Москвы
with urlopen('http://gis-lab.info/data/mos-adm/mo.geojson') as response:
    mosсow_district_geo = json.load(response)

# %%
# русско-англиский словарь названий районов
with open('ru_eng_district_names.pkl', 'rb') as f:
    ru_eng_district_names = pickle.load(f)

# %%
df_price = pd.DataFrame(zip(ru_eng_district_names.keys(), ru_eng_district_names.values()),
                        columns=['ru_name', 'eng_name'])

# %%
color = {'text': '#b3bdc7',
         'background_left': '#1f2630',
         'background_right': '#a7aeb5'}

# %%
help(dcc.RadioItems)
# Out:
# Help on class RadioItems in module dash.dcc.RadioItems:
#
# class RadioItems(dash.development.base_component.Component)
#  |  RadioItems(options=undefined, value=undefined, inline=undefined, style=undefined, className=undefined, inputStyle=undefined, inputClassName=undefined, labelStyle=undefined, labelClassName=undefined, id=undefined, loading_state=undefined, persistence=undefined, persisted_props=undefined, persistence_type=undefined, **kwargs)
#  |
#  |  A RadioItems component.
#  |  RadioItems is a component that encapsulates several radio item inputs.
#  |  The values and labels of the RadioItems is specified in the `options`
#  |  property and the seleced item is specified with the `value` property.
#  |  Each radio item is rendered as an input with a surrounding label.
#  |
#  |  Keyword arguments:
#  |
#  |  - options (list of dicts; optional):
#  |      An array of options, or inline dictionary of options.
#  |
#  |      `options` is a list of string | number | booleans | dict | list of
#  |      dicts with keys:
#  |
#  |      - disabled (boolean; optional):
#  |          If True, this option is disabled and cannot be selected.
#  |
#  |      - label (a list of or a singular dash component, string or number; required):
#  |          The option's label.
#  |
#  |      - title (string; optional):
#  |          The HTML 'title' attribute for the option. Allows for
#  |          information on hover. For more information on this attribute,
#  |          see
#  |          https://developer.mozilla.org/en-US/docs/Web/HTML/Global_attributes/title.
#  |
#  |      - value (string | number | boolean; required):
#  |          The value of the option. This value corresponds to the items
#  |          specified in the `value` property.
#  |
#  |  - value (string | number | boolean; optional):
#  |      The currently selected value.
#  |
#  |  - inline (boolean; default False):
#  |      Indicates whether labelStyle should be inline or not True:
#  |      Automatically set { 'display': 'inline-block' } to labelStyle
#  |      False: No additional styles are passed into labelStyle.
#  |
#  |  - style (dict; optional):
#  |      The style of the container (div).
#  |
#  |  - className (string; optional):
#  |      The class of the container (div).
#  |
#  |  - inputStyle (dict; optional):
#  |      The style of the <input> radio element.
#  |
#  |  - inputClassName (string; default ''):
#  |      The class of the <input> radio element.
#  |
#  |  - labelStyle (dict; optional):
#  |      The style of the <label> that wraps the radio input  and the
#  |      option's label.
#  |
#  |  - labelClassName (string; default ''):
#  |      The class of the <label> that wraps the radio input  and the
#  |      option's label.
#  |
#  |  - id (string; optional):
#  |      The ID of this component, used to identify dash components in
#  |      callbacks. The ID needs to be unique across all of the components
#  |      in an app.
#  |
#  |  - loading_state (dict; optional):
#  |      Object that holds the loading state object coming from
#  |      dash-renderer.
#  |
#  |      `loading_state` is a dict with keys:
#  |
#  |      - component_name (string; optional):
#  |          Holds the name of the component that is loading.
#  |
#  |      - is_loading (boolean; optional):
#  |          Determines if the component is loading or not.
#  |
#  |      - prop_name (string; optional):
#  |          Holds which property is loading.
#  |
#  |  - persistence (boolean | string | number; optional):
#  |      Used to allow user interactions in this component to be persisted
#  |      when the component - or the page - is refreshed. If `persisted` is
#  |      truthy and hasn't changed from its previous value, a `value` that
#  |      the user has changed while using the app will keep that change, as
#  |      long as the new `value` also matches what was given originally.
#  |      Used in conjunction with `persistence_type`.
#  |
#  |  - persisted_props (list of a value equal to: 'value's; default ['value']):
#  |      Properties whose user interactions will persist after refreshing
#  |      the component or the page. Since only `value` is allowed this prop
#  |      can normally be ignored.
#  |
#  |  - persistence_type (a value equal to: 'local', 'session', 'memory'; default 'local'):
#  |      Where persisted user changes will be stored: memory: only kept in
#  |      memory, reset on page refresh. local: window.localStorage, data is
#  |      kept after the browser quit. session: window.sessionStorage, data
#  |      is cleared once the browser quit.
#  |
#  |  Method resolution order:
#  |      RadioItems
#  |      dash.development.base_component.Component
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__ = wrapper(self, options=undefined, value=undefined, inline=undefined, style=undefined, className=undefined, inputStyle=undefined, inputClassName=undefined, labelStyle=undefined, labelClassName=undefined, id=undefined, loading_state=undefined, persistence=undefined, persisted_props=undefined, persistence_type=undefined, **kwargs)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from dash.development.base_component.Component:
#  |
#  |  __delitem__(self, id)
#  |      Delete items by ID in the tree of children.
#  |
#  |  __getitem__(self, id)
#  |      Recursively find the element with the given ID through the tree of
#  |      children.
#  |
#  |  __iter__(self)
#  |      Yield IDs in the tree of children.
#  |
#  |  __len__(self)
#  |      Return the number of items in the tree.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, id, item)
#  |      Set an element by its ID.
#  |
#  |  to_plotly_json(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from dash.development.base_component.Component:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from dash.development.base_component.Component:
#  |
#  |  REQUIRED = required
#  |
#  |  UNDEFINED = undefined

# %%
# устанавливаем параметры для элементов дэшборда
material_dict = {1: 'монолитный', 2: 'кирпично-монолитный', 3: 'кирпичный', 
                 4: 'панельный', 5: 'блочный', 6: 'деревянный'}

state_dict = {2: 'без ремонта', 3: 'евроремонт', 4: 'дизайнерский ремонт',
              1: 'косметический ремонт'}

reverse_material_dict = dict(zip(material_dict.values(), material_dict.keys()))
reverse_state_dict = dict(zip(state_dict.values(), state_dict.keys()))
                             
min_full_sq = 1
max_full_sq = 200
min_kitch_sq = 1

min_floor = 1
max_floor = df_data['floor'].max()
max_max_floor = df_data['max_floor'].max()

max_rooms = df_data['num_room'].max()

state_apartment = [state_dict[x] for x in sorted(df_data['state'].unique())]
material = [material_dict[x] for x in sorted(df_data['material'].unique())]


app = JupyterDash(__name__)

app.layout = html.Div(children=[


        html.Div(children=[

            #House prices in Moscow
            html.H1('Цены на недвижимость в Москве',
                    style={'textAlign': 'left', 
                           'font-family': 'Helvetica',
                           'font-size': 40,
                           'color': color['text']}),

            html.Label('Укажите параметры расчета',
                       style={'font-family': 'Helvetica',
                              'font-size': 20,
                              'color': color['text']}),

            html.Hr(),
            html.Label('Общая площадь [м2]', style={'font-family': 'Helvetica', 'color': color['text']}),
            dcc.Slider(
                min=min_full_sq,
                max=max_full_sq,
                step=1,
                marks=None,
                value=20,
                id='full_sq',
                tooltip={"placement": "bottom", "always_visible": True},
            ),
            
            html.Label('Жилая площадь [м2]', style={'font-family': 'Helvetica', 'color': color['text']}),
            dcc.Slider(
                min=1,
                step=1,
                marks=None,
                value=10,
                id='life_sq',
                tooltip={"placement": "bottom", "always_visible": True},
            ),
            
            html.Label('Площадь кухни [м2]', style={'font-family': 'Helvetica', 'color': color['text']}),
            dcc.Slider(
                min=1,
                step=1,
                marks=None,
                value=1,
                id='kitch_sq',
                tooltip={"placement": "bottom", "always_visible": True},
            ),
              
            html.Label('Количество комнат', style={'font-family': 'Helvetica', 'color': color['text']}),
            dcc.Dropdown(np.arange(1, max_rooms + 1), value=1, id='num_room'),


            html.Br(),
            html.Div(children=[
                
                html.Div(children=[
                    html.Label('Этаж', style={'font-family': 'Helvetica', 'color': color['text']}),
                    dcc.Dropdown(np.arange(min_floor, max_floor+1), value=1, id='floor')], style={'flex': 1}),

                html.Div(children=[
                    html.Label('Этажность здания', style={'font-family': 'Helvetica', 'color': color['text']}),
                    dcc.Dropdown(id='max_floor')], style={'flex': 1})
                
            ], style={'display': 'flex', 'flex-direction': 'row', 'align-self': 'flex-start', 'margin': 0}),

            html.Br(),
            html.Div(children=[
                
                html.Div(children=[
                    html.Label('Материал стен', style={'font-family': 'Helvetica', 'color': color['text']}),
                    dcc.RadioItems(material,
                                   value=material[0],
                                   id='material',
                                   labelStyle={'display': 'block'},
                                   style={'font-family': 'Helvetica', 'color': color['text']})], style={'flex': 1}),
                html.Div(children=[
                    html.Label('Состояние', style={'font-family': 'Helvetica', 'color': color['text']}),
                    dcc.RadioItems(state_apartment,
                                   value=state_apartment[0],
                                   id='state',
                                   labelStyle={'display': 'block'},
                                   style={'font-family': 'Helvetica', 'color': color['text']})], style={'flex': 1}),
            
            ], style={'display': 'flex', 'flex-direction': 'row', 'align-self': 'flex-start', 'margin': 0}),

            html.Br(),
            html.Label('Расстояние до Садового кольца [км]', style={'font-family': 'Helvetica', 'color': color['text']}),
            dcc.Input(value=1, type='number', id='sadovoe_km'),
            
            html.Br(),
            html.Label('Растояние до метро [км]', style={'font-family': 'Helvetica', 'color': color['text']}),
            dcc.Input(value=1, type='number', id='metro_km_avto'),
            

            
        ], style={'padding': 20, 'flex': 1, 'backgroundColor': color['background_left']}),

        html.Div(children=[
            html.A(),
            dcc.Graph(id='graph')
        ], style={'padding': 20, 'flex': 1, 'backgroundColor': color['background_right']})

], style={'display': 'flex', 'flex-direction': 'row', 'align-self': 'flex-start', 'margin': 0})


@app.callback(
    Output('graph', 'figure'),
    Input('full_sq', 'value'),
    Input('life_sq', 'value'),
    Input('kitch_sq', 'value'),
    Input('num_room', 'value'),
    Input('floor', 'value'),
    Input('max_floor', 'value'),
    Input('material', 'value'),
    Input('state', 'value'),
    Input('metro_km_avto', 'value'),
    Input('sadovoe_km', 'value')
)
def inp_func(full_sq, life_sq, kitch_sq, num_room, floor, max_floor, material, state, metro_km_avto, sadovoe_km):
    # создание заданного объекта
    most_freq_df['full_sq'] = full_sq
    most_freq_df['life_sq'] = life_sq
    most_freq_df['kitch_sq'] = kitch_sq
    most_freq_df['num_room'] = num_room
    most_freq_df['floor'] = floor
    most_freq_df['max_floor'] = max_floor
    most_freq_df['material'] = reverse_material_dict[material]
    most_freq_df['state'] = reverse_state_dict[state]
    most_freq_df['metro_km_avto'] = metro_km_avto
    most_freq_df['sadovoe_km'] = sadovoe_km

    temp_list = []
    for name in df_price['eng_name']:
        most_freq_df['sub_area'] = name
        # temp_most_freq_df = most_freq_df[most_freq_df['sub_area']==name]
        temp_list.append(float(loaded_model.predict(most_freq_df)))
    df_price['price'] = temp_list
    fig = px.choropleth_mapbox(df_price, geojson=mosсow_district_geo, locations="ru_name", color='price',
                               mapbox_style="carto-positron",
                               zoom=8.2, center={"lat": 55.60, "lon": 37.20},
                               featureidkey="properties.NAME",
                               labels={'ru_name': 'district'}
                               )
    fig.update_layout(margin={"r": 0, "t": 0, "l": 0, "b": 0},
                      height=700,
                      width=900)

    return fig

# настройка жилой площади кухни
@app.callback(
    Output('life_sq', 'max'),
    Input('full_sq', 'value')
)
def life_square(full_sq):
    return full_sq

# настройка площади кухни
@app.callback(
    Output('kitch_sq', 'max'),
    Input('full_sq', 'value'),
    Input('life_sq', 'value')
)
def kitch_square(full_sq, life_sq):
    return full_sq - life_sq

# настройка 'этажности'
@app.callback(
    Output('max_floor', 'options'),
    Output('max_floor', 'value'),
    Input('floor', 'value'),
)
def floor(floor):
    return np.arange(floor, 100), floor


if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Dash app running on http://127.0.0.1:8050/
